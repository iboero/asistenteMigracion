# %%
import os 
from docx import Document
from docx.document import Document as _Document
from docx.oxml.text.paragraph import CT_P
from docx.oxml.table import CT_Tbl
from docx.table import _Cell, Table
from docx.text.paragraph import Paragraph
from langchain_community.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings
from langchain.docstore.document import Document as docs
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import JsonOutputParser, StrOutputParser
from langchain.prompts import PromptTemplate
from operator import itemgetter
from langchain_core.runnables import RunnableLambda

# %%
def iter_block_items(parent):
    if isinstance(parent, _Document):
        parent_elm = parent.element.body
    elif isinstance(parent, _Cell):
        parent_elm = parent._tc
    elif isinstance(parent, _Row):
        parent_elm = parent._tr
    else:
        raise ValueError("something's not right")
    for child in parent_elm.iterchildren():
        if isinstance(child, CT_P):
            yield Paragraph(child, parent)
        elif isinstance(child, CT_Tbl):
            yield Table(child, parent)

def get_tabla_de_bandejas(doc):
    string = "Generación de Estructuras de Bandejas"
    seccion_hallada = False
    tabla_hallada = False
    for block in iter_block_items(doc):
        if tabla_hallada:
            break

        if isinstance(block, Paragraph) and not seccion_hallada:
            if string.strip() in block.text:
                seccion_hallada = True
        if seccion_hallada:
            if isinstance(block, Table):
                tabla_hallada = True
                tabla = block
    if tabla_hallada:
        tabla_lista = []
        for row in tabla.rows:
                tabla_lista.append([cell.text for cell in row.cells])
        return tabla_lista
    else:
        return -1
    


def get_tabla_de_campos(doc,bandeja):
    string = "Diseño de Tablas de Bandejas"
    seccion_hallada = False
    tabla_hallada = False
    bandeja_hallada = False

    for block in iter_block_items(doc):
        if tabla_hallada:
            break

        if isinstance(block, Paragraph) and not seccion_hallada:
            if string.strip() in block.text:
                seccion_hallada = True

        if isinstance(block, Paragraph) and seccion_hallada:
            if bandeja.strip() in block.text:
                bandeja_hallada = True
        if bandeja_hallada:
            if isinstance(block, Table):
                tabla_hallada = True
                tabla = block
    if tabla_hallada:
        tabla_lista = []
        for row in tabla.rows:
                tabla_lista.append([cell.text.strip() for cell in row.cells])
        return tabla_lista
    else:
        return -1

# %%
path = "C:/Users/iboero/Chat_w_PDF/data/raw_docs/Migracion/"
doc_paths = [x for x in os.listdir(path) if x[-5:]==".docx"]

lista_tabla_bandejas = {}
lista_elementos_bandejas = {}

for doc_path in doc_paths:
    doc = Document(path + doc_path)
    tabla_bandejas = get_tabla_de_bandejas(doc)
    lista_tabla_bandejas[doc_path[:-5]] = tabla_bandejas
    # print(tabla_bandejas)
    bandejas =  tabla_bandejas[1:]
    bandejas = [sublista[0] for sublista in bandejas]

    elementos_bandejas = {}
    for bandeja in bandejas:
        tabla = get_tabla_de_campos(doc, "Tabla "+bandeja.strip())
        if tabla != -1:
            elementos_bandejas[bandeja] = tabla
    lista_elementos_bandejas[doc_path[:-5]] = elementos_bandejas
    # print(doc_path, elementos_bandejas.keys())

# %%
class bandeja:
    def __init__(self,codigo,descripcion):
        self.codigo = codigo
        self.descripcion = descripcion
        self.largo = 0
        self.campos = []

    def add_campo(self,campo):
        self.largo += 1
        self.campos.append(campo)

    def get_campo(self,campo):
        for c in self.campos:
            if c.codigo.strip() == campo.strip():
                return c
        return -1
    

    
class campo:
    def __init__(self,codigo,descripcion,tipo,idx):
        self.codigo = codigo
        self.descripcion = descripcion
        self.idx = idx
        self.tipo = tipo

    
class manual:
    def __init__(self,codigo, desc_bandejas,lista_campos):
        self.codigo = codigo
        self.bandejas = self.generate_bandejas(desc_bandejas,lista_campos)

    def generate_bandejas(self,desc_bandejas,lista_campos):
        bjs_objects = []
        for b in desc_bandejas[1:]:
            if b[0] in lista_campos.keys():
                bj = bandeja(codigo=b[0],descripcion=b[1])
                for c in lista_campos[b[0]][1:]:
                    if len(c)>=4:
                        desc_extra = c[3]
                    else:
                        desc_extra = ''
                    c_obj = campo(codigo=c[0], descripcion=c[1]+' '+desc_extra,tipo=c[2],idx=bj.largo)
                    bj.add_campo(c_obj)
                bjs_objects.append(bj)
        return bjs_objects
    
    def get_bandeja(self,bandeja):
        for b in self.bandejas:
            if b.codigo.strip() == bandeja.strip():
                return b
        return -1

# %%
manuales_obj = {}
for m in lista_elementos_bandejas.keys():
    m_obj = manual(m,lista_tabla_bandejas[m],lista_elementos_bandejas[m])
    manuales_obj[m] = m_obj



def get_desc_bandejas(manual):
    manual = manuales_obj[manual]
    string = ""
    for b in manual.bandejas:
        string +=  b.codigo + ': ' + b.descripcion + '\n'
    return string

# %%
import dill as pkl
filename = 'manuales_object.pkl'
with open(filename, 'wb') as file:
    pkl.dump(manuales_obj, file)

# %%
db_ret = Chroma(persist_directory="db_campos", embedding_function=OpenAIEmbeddings())
db_ret.delete_collection()

d = []

for m_name in manuales_obj:
    m = manuales_obj[m_name]
    for b in m.bandejas:
        for c in b.campos:
            print({"manual":m.codigo,"bandeja":b.codigo, "campo":c.codigo},c.descripcion)
            d.append(docs(page_content=c.descripcion, metadata={"manual":m.codigo,"bandeja":b.codigo, "campo":c.codigo,"tipo":c.tipo}))
            
embedding_function = OpenAIEmbeddings()
db = Chroma.from_documents(d, embedding_function, persist_directory="db_campos")
# Out:
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjEmp'} BnjEmp Empresa
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjCod'} Código de Bandeja Código de bandeja.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjSuc'} Sucursal Sucursal donde se otorgó el Acuerdo
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjMda'} Moneda Moneda en el que se otorgó.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjPap'} Papel No corresponde
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjCta'} Cuenta Cuenta cliente.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjOpe'} Operación Número identificador del Contrato de Acuerdo.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjSbOp'} Suboperación Suboperación = Subcuenta
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjTOpe'} Tipo de Operación No corresponde
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjSdo'} Saldo (Importe) Valor del Acuerdo
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjFval'} F/valor Fecha de alta de la operación.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjFvto'} F/vencimiento Fecha de vencimiento-
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjFulm'} Fecha último movimiento Igual a  de Alta de la Operación
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjPzo'} Plazo Cantidad de días desde la fecha valor a la fecha de vencimiento. Depende de la definición de tipos de días realizada.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjTtas'} Tipo de Tasa Valores válidos: 1 (tasa efectiva anual), 2 (tasa nominal anual), 3 (tasa efectiva mensual), 4 (tasa nominal mensual).
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjTasa'} Tasa Tasa original pactada del crédito.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjTmor'} Tasa de mora No corresponde
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjTtac'} Tipo Tasa de Corte Se carga desde 024
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjTasc'} Tasa de Corte Se carga desde 024
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjTdia'} Tipo de días Valores válidos: 1 (plazo comercial), 2 (plazo calendario).
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjTvto'} Tipo de Ajuste en Vto. Valores válidos: A (ajuste anterior al vencimiento), P (ajuste posterior al vencimiento), N (no corresponde).
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjTano'} Tipo de año Valores válidos: 1 (año comercial), 2 (año calendario).
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjTint'} Tipo de cálculo de interés No Corresponde
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjDrev'} Días p/revisión Tasa Periodicidad de la revisión de tasa. Válido para tipos los Acuerdos a Tasa Revisable.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjImp'} Importe Monto del Acuerdo.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjIm2'} Importe 2
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjIm3'} Importe 3
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjIm4'} Importe 4
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjIm5'} Importe 5
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjIm6'} Importe 6
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjIm7'} Importe 7
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjIm8'} Importe 8
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjIm9'} Importe 9
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjIm10'} Importe 10
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjIm11'} Importe 11
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjIm12'} Importe 12
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjIm13'} Importe 13
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjIm14'} Importe 14
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjIm15'} Importe 15
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjVt11'} Vencimiento 11
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjVt12'} Vencimiento 12
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjVt13'} Vencimiento 13
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjVt14'} Vencimiento 14
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjVt15'} Vencimiento 15
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjPre'} Precio No corresponde
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjPre1'} Precio No corresponde.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjTcbi'} Tcbi No corresponde.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjTcbi1'} Tcbi1 No corresponde.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjArb'} Arb No corresponde.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjArb1'} Arb1 No corresponde.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjMd'} Md No corresponde.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjMd1'} Md1 No corresponde.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjNume'} Intereses al Vencimiento No corresponde
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjFnum'} Fecha última revisión tasa Última fecha en la que se revisó la tasa de la operación. Válido los acuerdos a tasa revisable.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjAfiv'} Afectada por IVA? No corresponde.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjCbcu'} Cod. actividad BCU No corresponde.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjStat'} Status Código de status de la operación migrada (0).
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjAvis'} Aviso (Vto., etc.) No corresponde.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjPlus'} Tasa Plus Valor de la tasa plus definido en el alta de la operación. Válido para los Acuerdos de tasa revisable.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjEven'} Numerador de Eventos No corresponde.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjFe99'} Fecha de Baja No corresponde, dado que no se migran acuerdos cancelados.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjCltcod'} BnjCltcod Código de clase de tasa
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjPeriod'} Período (Itper) No corresponde.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjOK'} Marca registro OK S/N Ver descripción de estados en 1.4.2.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjCoT1'} Auxiliar Texto 1
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjCoT2'} Auxiliar Texto 2
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjCoT3'} Auxiliar Texto 3
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjCoT4'} Auxiliar Texto 4
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjCoN1'} Auxiliar Numerico 1
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ002', 'campo': 'BnjCoN2'} Auxiliar Numerico 2
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ012', 'campo': 'BnjEmp'} Empresa Ídem BNJ002.BnjEmp.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ012', 'campo': 'BnjCod'} Código de Bandeja Ídem BNJ002.BnjCod.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ012', 'campo': 'BnjAosuc'} Sucursal Ídem BNJ002.BnjSuc.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ012', 'campo': 'BnjAomda'} Moneda Ídem BNJ002.BnjMda.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ012', 'campo': 'BnjAopap'} Papel Ídem BNJ002.BnjPap.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ012', 'campo': 'BnjAocta'} Cuenta Ídem BNJ002.BnjCta.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ012', 'campo': 'BnjAooper'} Operación Ídem BNJ002.BnjOpe.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ012', 'campo': 'BnjAosbop'} Suboperación Ídem BNJ002.BnjSbOp.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ012', 'campo': 'BnjAotope'} Tipo de operación Ídem BNJ002.BnjTOpe.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ012', 'campo': 'BnjEvcorr'} Correlativo evento Código indicativo de secuencia del evento.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ012', 'campo': 'BnjEvtipo'} Tipo de evento Valores válidos 3, 4, 5 y 6.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ012', 'campo': 'BnjEvfval'} Fecha valor Fecha desde la cual rige el evento de tasa.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ012', 'campo': 'BnjEvttas'} Tipo de tasa Valores válidos: 1 (tasa efectiva anual), 2 (tasa nominal anual), 3 (tasa efectiva mensual), 4 (tasa nominal mensual).
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ012', 'campo': 'BnjEvtasa'} Evtasa Tasa revisada del crédito.
# {'manual': 'Manual Acuerdos de Sobregiro', 'bandeja': 'BNJ012', 'campo': 'BnjEvEst'} Estado Ver descripción de estados en 1.4.2.
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ003', 'campo': 'BnjChCodE'} Empresa
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ003', 'campo': 'BnjChCodB'} Codigo de Bandeja
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ003', 'campo': 'BnjChMod'} Modulo
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ003', 'campo': 'BnjChSuc'} Sucursal
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ003', 'campo': 'BnjChMda'} Moneda
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ003', 'campo': 'BnjChPap'} Papel
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ003', 'campo': 'BnjChCta'} Cuenta
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ003', 'campo': 'BnjChOpe'} Operacion
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ003', 'campo': 'BnjChSbo'} SubOperacion
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ003', 'campo': 'BnjChTop'} Tipo de Operacion
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ003', 'campo': 'BnjChIni'} Cheque Inicial
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ003', 'campo': 'BnjChCnt'} Cantidad
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ003', 'campo': 'BnjChLst'} Lista de Cheques
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ003', 'campo': 'BnjChSer'} Serie de Chequera
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ003', 'campo': 'BnjChSts'} Estado de la Chequera
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ003', 'campo': 'BnjChFch'} Fecha entregada
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ003', 'campo': 'BnjChTpo'} Tipo de Chequera
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ003', 'campo': 'BnjChOk'} Marca de registro Ok
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ003', 'campo': 'BnjChPrc'} Marca de Procesado
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ003', 'campo': 'BnjChChk'} Analiza Cheques?
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ010', 'campo': 'CchqEmp'} Empresa
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ010', 'campo': 'CchqMod'} Módulo
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ010', 'campo': 'CchqSuc'} Sucursal
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ010', 'campo': 'CchqMda'} Moneda
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ010', 'campo': 'CchqPap'} Papel
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ010', 'campo': 'CchqCta'} Cuenta
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ010', 'campo': 'CchqOper'} Operación
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ010', 'campo': 'CchqSbop'} Sub Operación
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ010', 'campo': 'CchqTOp'} Tipo de Operación
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ010', 'campo': 'CchqNro'} Número de Cheque
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ010', 'campo': 'CchqFech'} Fecha
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ010', 'campo': 'CchqRel'} Correlativo
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ010', 'campo': 'CchqEstAnt'} Estado Anterior
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ010', 'campo': 'CchqMot'} Motivo
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ010', 'campo': 'CchqAux1'} CchqAux1
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ010', 'campo': 'CchqAux2'} CchqAux2
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ010', 'campo': 'CChqPgcod'} CChqPgcod
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ010', 'campo': 'CchqHcSuc'} CchqHcSuc
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ010', 'campo': 'CChqHcMod'} CChqHcMod
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ010', 'campo': 'CchqHcTrn'} CchqHcTrn
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ010', 'campo': 'CchqHcNrel'} CchqHcNrel
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ010', 'campo': 'CchqHfcont'} CchqHfcont
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ010', 'campo': 'CchqHcord'} CchqHcord
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ010', 'campo': 'CchqHcSubo'} CchqHcSubo
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03Emp'} Empresa
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03Cod'} Código Bandeja
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03Ped'} Nro.Solicitud
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03Proc'} Procesado
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03CSu'} Sucursal del Usuario
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03TDo'} Tipo de Chequera
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03EstS'} Estado de Solicitud
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03Id1'} Id. Titular 1, Retiro
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03Id2'} Id. Titular 2, Retiro
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03Id3'} Id. Titular 3, Retiro
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03Nm1'} Nomb. Tit. 1
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03Nm2'} Nomb. Tit. 2
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03Nm3'} Nomb. Tit. 3
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03SucR'} Sucursal donde Retira
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03CntCh'} Cantidad de Cheques
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03FPed'} Fecha de Pedido
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03FdPv'} Fecha Vino Proveedor
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03EmpC'} Empresa Cuenta
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03Suc'} Sucursal Cuenta
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03Mod'} Modulo Cuenta
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03Mda'} Moneda Cuenta
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03Pap'} Papel Cuenta
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03Cta'} Cuenta
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03Op'} Operacion Cuenta
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03SbOp'} Sub. Operacion.
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03TOp'} Tipo de Operación.
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03CIn'} Cheque Inicial
# {'manual': 'Manual Chequeras', 'bandeja': 'BJCH03', 'campo': 'BCH03UsI'} Usuario que Ingresa
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7Emp'} Empresa
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7Band'} Bandeja
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7Mod'} Modulo
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7Suc'} Sucursal
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7Mda'} Moneda
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7Pap'} Papel
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7Cta'} Cuenta Cliente
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7Ope'} Operacion
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7Sub'} Sub Operacion
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7Top'} Tipo de Operacion
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7Chq'} Cheque
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7TChq'} Tipo de Chequera
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7TDocB'} Tipo Documento Beneficiario
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7DocB'} Documento Beneficiario
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7NomB'} Nombre Beneficiario
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7TDocO'} Tipo Documento Otorgante
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7DocO'} Documento Otorgante
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7NomO'} Nombre Otorgante
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7ImpL'} Importe en Letras
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7Mnto'} Monto
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7FVto'} Fecha Vencimiento
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7FImp'} Fecha Impresion
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7MEm1'} Motivo Emision 1
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7MEm2'} Motivo Emision 2
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7MEm3'} Motivo Emision 3
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7MEm4'} Motivo Emision 4
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7MEm5'} Motivo Emision 5
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ007', 'campo': 'Bnj7Est'} Estado
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ222', 'campo': 'BnjDenEmp'} Empresa
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ222', 'campo': 'BnjDenCod'} Codigo de Bandeja
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ222', 'campo': 'BnjDenSuc'} Sucursal
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ222', 'campo': 'BnjDenMda'} Moneda
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ222', 'campo': 'BnjDenPap'} Papel
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ222', 'campo': 'BnjDenCta'} Cuenta
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ222', 'campo': 'BnjDenOpe'} Operacion
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ222', 'campo': 'BnjDenSbOp'} SubOperacion
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ222', 'campo': 'BnjDenTOpe'} Tipo de Operacion
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ222', 'campo': 'BnjDenCorr'} Correlativo
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ222', 'campo': 'BnjDenCte'} Denunciante
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ222', 'campo': 'BnjDenu'} Denuncia
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ222', 'campo': 'BnjDenP'} Denuncia Policial
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ222', 'campo': 'BnjDenPFch'} Fecha de Den. Policial
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ222', 'campo': 'BnjDenJ'} Denuncia Judicial
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ222', 'campo': 'BnjDenJFch'} Fecha de Den. Judicial
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ222', 'campo': 'BnjTexDenJ'} Texto de Denuncia Judicial
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ222', 'campo': 'BnjDes'} Cheque Desde
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ222', 'campo': 'BnjHas'} Cheque Hasta
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ222', 'campo': 'BnjTxt1'} Textos Asociados
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ222', 'campo': 'BnjTxt2'} Textos Asociados
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ222', 'campo': 'BnjEstAnt'} Estado Anterior
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ006', 'campo': 'BcleEmp'} Empresa
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ006', 'campo': 'BcleBnd'} Bandeja
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ006', 'campo': 'BcleMod'} Módulo
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ006', 'campo': 'BcleSuc'} Sucursal
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ006', 'campo': 'BcleMda'} Moneda
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ006', 'campo': 'BclePap'} Papel
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ006', 'campo': 'BcleCta'} Cuenta Cliente
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ006', 'campo': 'BcleOpe'} Operación
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ006', 'campo': 'BcleSub'} Sub Operación
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ006', 'campo': 'BcleTOp'} Tipo de Operación
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ006', 'campo': 'BclE1Fch'} Fecha
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ006', 'campo': 'Bcle1Hra'} Hora
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ006', 'campo': 'Bcle1Prd'} Producto
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ006', 'campo': 'Bcle1Bol'} Boleta
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ006', 'campo': 'Bcle1Chq'} Cheque
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ006', 'campo': 'Bcle1Bco'} Banco
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ006', 'campo': 'Bcle1BSuc'} Sucursal del Banco
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ006', 'campo': 'Bcle1CP'} Código Postal
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ006', 'campo': 'Bcle1CtaL'} Cuenta del Librador
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ006', 'campo': 'Bcle1Pza'} Plaza
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ006', 'campo': 'Bcle1Pzo'} Plazo
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ006', 'campo': 'Bcle1TChq'} Tipo de Cheque
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ006', 'campo': 'Bcle1Imp'} Importe
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ006', 'campo': 'Bcle1Est'} Estado
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ006', 'campo': 'Bcle1Mda'} Moneda del Cheque
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ006', 'campo': 'Bcle1MtVto'} Motivo del Vencimiento
# {'manual': 'Manual Chequeras', 'bandeja': 'BNJ006', 'campo': 'Bcle1MEst'} Estado en Proceso de Migracion
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjEmp'} Empresa Empresa
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjCod'} Código de Bandeja Código de bandeja.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjSuc'} Sucursal Sucursal donde se otorgó el crédito.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjMda'} Moneda Moneda en el que se otorgó.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjPap'} Papel No corresponde.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjCta'} Cuenta Cuenta cliente
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjOpe'} Operación No corresponde. Grabarlo en 0
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjSbOp'} Suboperación Se migra con el número de producto de Cuenta Vista.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjTOpe'} Tipo de Operación Código identificador del tipo de producto.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjSdo'} Saldo (Importe) Saldo producto CV cero o positivo
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjFval'} F/valor Fecha de alta de la cuenta vista.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjFvto'} F/vencimiento No corresponde.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjFulm'} Fecha último movimiento Si no existe último movimiento debe de ingresar la fecha de creación.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjPzo'} Plazo No corresponde.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjTtas'} Tipo de Tasa Valores válidos: 1 (tasa efectiva anual), 2 (tasa nominal anual), 3 (tasa efectiva mensual), 4 (tasa nominal mensual).
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjTasa'} Tasa Tasa original pactada para la Cuenta Vista en caso de pagar intereses.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjTmor'} Tasa de mora No corresponde
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjTtac'} Tipo Tasa de Corte Valores válidos: 1 (tasa efectiva anual), 2 (tasa nominal anual), 3 (tasa efectiva mensual), 4 (tasa nominal mensual).
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjTasc'} Tasa de Corte Tasa de corte original.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjTdia'} Tipo de días Valores válidos: 1 (plazo comercial), 2 (plazo calendario).
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjTvto'} Tipo de Ajuste en Vencimiento Valores válidos: A (ajuste anterior al vencimiento), P (ajuste posterior al vencimiento), N (no corresponde).
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjTano'} Tipo de año Valores válidos: 1 (año comercial), 2 (año calendario).
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjTint'} Tipo de cálculo de interés No corresponde.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjDrev'} Días p/revisión Tasa No corresponde.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjImp'} Importe No corresponde
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjIm2'} Importe 2 Intereses (rel 1)
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjIm3'} Importe 3 Resultados (rel 2 o 3)
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjIm4'} Importe 4 Sobregiro amparado (rel 20)
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjIm5'} Importe 5 Sobregiro NO amparado (rel 31)
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjIm6'} Importe 6 Pendiente Comisión Bajo Promedio (rel 29)
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjIm7'} Importe 7 Pendiente Comisión Estado de Cuenta (rel 79)
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjIm8'} Importe 8 Bloqueos (rel 166)
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjIm9'} Importe 9 Embargos (rel 167)
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjIm10'} Importe 10 Pendiente Comisión Cantidad de Movimientos (rel 69)
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjIm11'} Importe 11 Bloqueos con vto.(vt11)
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjIm12'} Importe 12 Previsiones Sobregiro (por el total)
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjIm13'} Importe 13 Sin uso
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjIm14'} Importe 14 Importe 14 - Sin uso
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjIm15'} Importe 15 Importe 15 - Sin uso
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjVt11'} Vencimiento 11 Vencimiento de bloqueo(im11)
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjVt12'} Vencimiento 12
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjVt13'} Vencimiento 13
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjVt14'} Vencimiento 14
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjVt15'} Vencimiento 15
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': ''}
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjPre'} Precio No corresponde
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjPre1'} Saldo Deudor/Acreedor Para CC - 1 - Deudor, 2 - Acreedor. Para CA 0 siempre.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjTcbi'} Tcbi No corresponde.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjTcbi1'} Tcbi1 No corresponde.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjArb'} Arb No corresponde.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjArb1'} Arb1 No corresponde.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjMd'} Md No corresponde.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjMd1'} Md1 No corresponde.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjNume'} Intereses al Vencimiento No corresponde.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjFnum'} Fecha última revisión tasa La fecha de integración al paquete en caso de pertenecer a un paquete.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjAfiv'} Afectada por IVA? No corresponde.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjCbcu'} Cod. actividad BCU No corresponde.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjStat'} Status Código de status de la operación migrada (Valores válidos 81 (inactiva) o 0)
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjAvis'} Aviso (Vto., etc.) No corresponde.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjPlus'} Tasa Plus No corresponde.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjEven'} Numerador de Eventos No corresponde.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjFe99'} Fecha de Baja La fecha en que se dio de baja la cuenta
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjCltcod'} BnjCltcod Código de clase de tasa
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjPeriod'} Período (Itper) Número del paquete que integra
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjOK'} Marca registro OK S/N Ver descripción de estados.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjCoT1'} Auxiliar Texto 1 Campo Auxiliar
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjCoT2'} Auxiliar Texto 2 Campo Auxiliar
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjCoT3'} Auxiliar Texto 3 Campo Auxiliar
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjCoT4'} Auxiliar Texto 4 Campo Auxiliar
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjCoN1'} Auxiliar Numerico 1 Campo Auxiliar
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ002', 'campo': 'BnjCoN2'} Auxiliar Numerico 2 Campo Auxiliar
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD211', 'campo': 'BD211Cod'} BD211Cod Empresa
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD211', 'campo': 'BD211Mod'} BD211Mod Módulo (20 - Cuenta Corriente o 21 - Caja de Ahorro)
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD211', 'campo': 'BD211Suc'} BD211Suc Sucursal de la Cuenta Vista
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD211', 'campo': 'BD211Mda'} BD211Mda Moneda
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD211', 'campo': 'BD211Pap'} BD211Pap No corresponde
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD211', 'campo': 'BD211Cta'} BD211Cta Cuenta
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD211', 'campo': 'BD211Oper'} BD211Oper No corresponde. Grabarlo en 0
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD211', 'campo': 'BD211SbOp'} BD211SbOp Suboperación de la cuenta vista
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD211', 'campo': 'BD211TpOp'} BD211TpOp Tipo de Operación
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD211', 'campo': 'BD211CodD'} Código de Domicilio Código de domicilio
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD211', 'campo': 'BD211Calle'} Calle Calle a donde se va a realizar el envío
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD211', 'campo': 'BD211Nro'} Número Número
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD211', 'campo': 'BD211Ap'} Apartamento Apartamento
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD211', 'campo': 'BD211Loc'} Localidad Localidad
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD211', 'campo': 'BD211Dept'} Código de Departamento Código de Departamento
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD211', 'campo': 'BD211Pais'} País País
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD211', 'campo': 'BD211CodPo'} Código Postal Código Postal
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD211', 'campo': 'BD211Casil'} Casilla de correo Casilla de Correo
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD211', 'campo': 'BD211Est'} Estado Ver descripción de estados en 1.4.2.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCvCodE'} Empresa
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCvCodB'} Codigo de Bandeja
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCvMod'} Modulo
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCvMda'} Moneda
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCvPap'} Papel
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCvCta'} Cuenta
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCvSuc'} Sucursal
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCvOpe'} Operacion
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCvSbo'} SubOperacion
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCvTop'} Tipo de Operacion
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCvCsp'} Comision sobre promedio
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCvSmo'} Comision sobre movimiento
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCvCch'} Cobra Chequera
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCvPin'} Paga interes
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCvCin'} Cobra interes por sobregiro?
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCvSbg'} Sobregiro Autorizado
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCvCau'} Cobertura Automatica
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCvEst'} Alta en Agencia o Corresponsal
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCvPmi'} Pago mensual de intereses
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCvNom'} Nombre de Subcuenta
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCvFcb'} Fecha de Baja
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCvUsb'} Usuario que dio la baja
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCvWsb'} Workstation de la baja
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCvTce'} Tipo de cambio especial ?
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCvFol'} Nro. de folio (extracto)
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCv1Fre'} Frecuencia
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCv1Fol'} Folio
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCv1Ulf'} Fecha Hasta de Ultima Emision
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCv1Imp'} Impreso ?
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCv1Tde'} Nro. de Tarjeta de Debito
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCv1Sda'} Saldo de la Ultima Emision
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCv1Aux1'} Auxiliar 1
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCv1Aux2'} Auxiliar 2
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCv1Aux3'} Auxiliar 3
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCv1Aux4'} Auxiliar 4
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCv1Aux5'} Auxiliar 5
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCv1Aux6'} Auxiliar 6
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCv1Aux7'} Auxiliar 7
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCvOk'} Marca de registro Ok
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BNJ004', 'campo': 'BnjCvPrc'} Marca de Procesado
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BnjEmp'} BnjEmp Empresa
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BnjCod'} Código de Bandeja Código de Bandeja.
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016Suc'} Sucursal Sucursal
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016Mda'} Moneda Moneda
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016Pap'} Papel No corresponde
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016Cta'} Cuenta Cuenta
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016Ope'} Operación No corresponde. Grabarlo en 0
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016SbOp'} Suboperación Número de la cuenta vista
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016TOpe'} Tipo de Operación Tipo de producto
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016SucOr'} Sucursal Origen del Mov. Sucursal en donde se efectuó el movimiento
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016Corr'} Correlativo Indica el número de movimiento
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016Corr1'} Correlativo 1 Indica el número de movimiento
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016FCon'} Fecha Contabilizacion Fecha de contabilización del movimiento
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016FVal'} Fecha Valor del Mov. Fecha valor del movimiento
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016CMov'} Cod. Mov. Código de Movimiento
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016Ref'} Referencia Referencia (texto que aclare movimiento)
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016Txt'} Texto Libre
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016Imp'} Importe Importe del movimiento
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016DH'} Debe/Haber Si corresponde a un débito (1) o a un crédito (2).
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016NumCh'} Num. Cheque Número de cheque (si corresponde a un pago de cheque)
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016Ax1'} BD016Ax1 Subordinal de la Transacción
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016Ax2'} BD016Ax2 No corresponde
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016Ax3'} BD016Ax3 No corresponde
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016Ax4'} BD016Ax4 No corresponde
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016Ax5'} BD016Ax5 No corresponde
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016Ax6'} BD016Ax6 No corresponde
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016Sact'} Estado del Registro Ingresarlo en 1
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016Mod'} Módulo CC/CA A que módulo corresponde 20 - Cuentas Corrientes 21 -  Caja de ahorros
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016SIni'} Saldo Anterior al movimiento
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016SAct'} Saldo Posterior al movimiento
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016NumCh'} Num. Cheque
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016CCONT'} Código de Contabilización
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016RUT'} RUT del Banco
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016FACT'} Factura
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016MFACT'} Moneda de Factura
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016TCAMB'} Tipo de Cambio
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016Imp1'} Importe Base
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016Imp2'} Importe IVA
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016Imp3'} Importe 3
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016Num1'} Tipo de Transacción
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016Num2'} Medio de Pago
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016Num3'} Nro POS
# {'manual': 'Manual Cuentas Vistas', 'bandeja': 'BJD016', 'campo': 'BD016Num4'} Nro Ticket POS
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001Band'} Bandeja
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001Pais'} País del Documento País del documento de la persona (FST013).
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001Tdoc'} T/ Documento Tipo de documento de la persona. Debe ser de acuerdo al tipo de persona (FST014).
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001Ndoc'} Documento Número de documento de la persona; no nulo. (Dato Obligatorio).
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001Tipo'} Tipo de Persona Física (‘F’) o Jurídica (‘J’).
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001Nom'} Nombre de Persona Nombre de la persona si es física o jurídica.
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001Falt'} Fecha Alta Fecha en que ingresó al Sistema.
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001Exent'} Exento de I.V.A. No corresponde.
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001ResIn'} Responsable Inscripto No corresponde.
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001ResNo'} Responsable No Inscripto No corresponde.
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001NoRes'} No Responsable No corresponde.
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001ConsF'} Consumidor Final No corresponde.
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001BceAj'} Ajusta Balance por Inflación No corresponde.
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001IngBr'} Ingresos Brutos No corresponde.
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001ImpIn'} Impuestos Internos No corresponde.
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001NroBr'} No. Ingresos Brutos No corresponde.
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001NroIn'} No. Impuestos Internos Actividad Económica Jurídicas
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001Rg312'} Retención IVA S/Proveedores No corresponde.
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001Rg333'} Retención IVA S/Clientes No corresponde.
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001Rg278'} Retención Impuestos Ganancias No corresponde.
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001InstF'} Es Inst. Financiera Pesn02 En caso de tratarse de una persona jurídica que es Institución Financiera, debe indicarse con la letra ‘S’.
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001Pesn03'} Pesn03 Categoría, Comercial ‘S’ de Consumo ‘N’.
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BE001SCnd'} Condición Imp. a los Sellos No corresponde.
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BE001SJur'} Jurisdicción p/Imp. Sellos Indica si es Vinculad a la empresa, se marca con 1
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BE001GCnd'} Condición Imp. a las Ganancias No aplica
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BE001Prov'} Proveedor del Banco? No aplica. Se administra a nivel de cuenta
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BE001TAlt'} Tipo de Alta Tipo de Alta para ingresar la persona (FST106).
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BE001ICod'} Código No corresponde.
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BE001OCod'} Código No corresponde.
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BE001DstCo'} Canal de Distribución De qué forma decidió ser persona del Banco (FST107).
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001Est'} Estado Ver descripción de estados en 1.4.2.
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001DGI'} Número de DGI Dato no obligatorio.
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001BPS'} Número de BPS Dato no obligatorio.
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001FPDGI'} Fecha presentación DGI Dato no obligatorio.
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001FVDGI'} Fecha Vencimiento DGI Dato no obligatorio.
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001FPBPS'} Fecha presentación BPS Dato no obligatorio.
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001FVBPS'} Fecha Vencimiento BPS Dato no obligatorio.
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001TIPEM'} Tipo de Empresa Dato no obligatorio.
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001COOP'} Categoría Categoria (Consumo (N) , Comercial (S)  o Comercial Asimilable a Consumo (A))
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001AUXI1'} Auxiliar Manejo interno sistema de migración
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD001', 'campo': 'BD001AXX'} Correlativo para paralelizar Manejo interno sistema de migración
# {'manual': 'Manual Cuentas y Personas', 'bandeja': 'BJD002', 'campo': 'BD002Band'} Bandeja
# ...
# {'manual': 'Manual Préstamos', 'bandeja': 'BNJ602', 'campo': 'B602ISe5'} Importe a Cobrar Importe a Cobrar para Seguro 5
# {'manual': 'Manual Préstamos', 'bandeja': 'BNJ602', 'campo': 'B602ISA5'} Importe Valor Comercial 5 Importe valor comercial Garantía Seguro 5
# {'manual': 'Manual Préstamos', 'bandeja': 'BNJ602', 'campo': 'B602SSe1'} Saldo Seguro 1 Saldo Seguro 1
# {'manual': 'Manual Préstamos', 'bandeja': 'BNJ602', 'campo': 'B602SSe2'} Saldo Seguro 2 Saldo Seguro 2
# {'manual': 'Manual Préstamos', 'bandeja': 'BNJ602', 'campo': 'B602SSe3'} Saldo Seguro 3 Saldo Seguro 3
# {'manual': 'Manual Préstamos', 'bandeja': 'BNJ602', 'campo': 'B602SSe4'} Saldo Seguro 4 Saldo Seguro 4
# {'manual': 'Manual Préstamos', 'bandeja': 'BNJ602', 'campo': 'B602SSe5'} Saldo Seguro 5 Saldo Seguro 5
# {'manual': 'Manual Préstamos', 'bandeja': 'BJR601', 'campo': 'BnjEmp'} Empresa Ídem BNJ002.BnjEmp.
# {'manual': 'Manual Préstamos', 'bandeja': 'BJR601', 'campo': 'BnjCod'} Código de Bandeja Ídem BNJ002.BnjCod.
# {'manual': 'Manual Préstamos', 'bandeja': 'BJR601', 'campo': 'Bnjp3cod'} Empresa Crédito
# {'manual': 'Manual Préstamos', 'bandeja': 'BJR601', 'campo': 'Bnjp3mod'} Módulo Crédito
# {'manual': 'Manual Préstamos', 'bandeja': 'BJR601', 'campo': 'Bnjp3suc'} Sucursal Crédito Ídem BNJ002.BnjSuc.
# {'manual': 'Manual Préstamos', 'bandeja': 'BJR601', 'campo': 'Bnjp3cta'} Cuenta Crédito Ídem BNJ002.BnjMda.
# {'manual': 'Manual Préstamos', 'bandeja': 'BJR601', 'campo': 'Bnjp3mda'} Moneda Crédito Ídem BNJ002.BnjPap.
# {'manual': 'Manual Préstamos', 'bandeja': 'BJR601', 'campo': 'Bnjp3pap'} Papel Crédito Ídem BNJ002.BnjCta.
# {'manual': 'Manual Préstamos', 'bandeja': 'BJR601', 'campo': 'Bnjp3oper'} Operación Crédito Idem BNJ002.BnjOpe.
# {'manual': 'Manual Préstamos', 'bandeja': 'BJR601', 'campo': 'Bnjp3sbop'} Suboperación Crédito Idem BNJ002.BnjSbOp.
# {'manual': 'Manual Préstamos', 'bandeja': 'BJR601', 'campo': 'Bnjp3tope'} Tipo de Operación Crédito Idem BNJ002.BnjTOpe.
# {'manual': 'Manual Préstamos', 'bandeja': 'BJR601', 'campo': 'Bnjp3corr'} Correlativo Correlativo de instrucción de cobro.
# {'manual': 'Manual Préstamos', 'bandeja': 'BJR601', 'campo': 'Bnjp4cod'} Empresa Débito Clave de la instrucción de cobro (código de empresa, módulo, sucursal, moneda, papel, cuenta, operación, Suboperación, tipo de operación).
# {'manual': 'Manual Préstamos', 'bandeja': 'BJR601', 'campo': 'Bnjp4mod'} Módulo Débito
# {'manual': 'Manual Préstamos', 'bandeja': 'BJR601', 'campo': 'Bnjp4suc'} Sucursal Débito
# {'manual': 'Manual Préstamos', 'bandeja': 'BJR601', 'campo': 'Bnjp4cta'} Cuenta Débito
# {'manual': 'Manual Préstamos', 'bandeja': 'BJR601', 'campo': 'Bnjp4mda'} Moneda Débito
# {'manual': 'Manual Préstamos', 'bandeja': 'BJR601', 'campo': 'Bnjp4pap'} Papel Débito
# {'manual': 'Manual Préstamos', 'bandeja': 'BJR601', 'campo': 'Bnjp4oper'} Operación Débito
# {'manual': 'Manual Préstamos', 'bandeja': 'BJR601', 'campo': 'Bnjp4sbop'} Suboperación Débito
# {'manual': 'Manual Préstamos', 'bandeja': 'BJR601', 'campo': 'Bnjp4tope'} Tipo de Operación Débito
# {'manual': 'Manual Préstamos', 'bandeja': 'BJR601', 'campo': 'Bnjp4Sobr'} Admite Sobregiro Indica si el registro de la instrucción admite sobregiro.
# {'manual': 'Manual Préstamos', 'bandeja': 'BJR601', 'campo': 'Bnjp4Parc'} Admite cobros parciales Indica si el registro de la instrucción puede utilizarse parcialmente para el cobro.
# {'manual': 'Manual Préstamos', 'bandeja': 'BJR601', 'campo': 'Bnjp4Est'} Estado del Registro Ver descripción de estados en 1.4.2.
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdCodE'} Empresa Empresa
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdCodB'} Código de Bandeja Código de bandeja. En general 101 es correcto.
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdSuc'} Sucursal Sucursal del Saldo Contable
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdRub'} Rubro Rubro (FSD014).
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdMda'} Moneda Moneda del Saldo Contable. (FST005).
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdPap'} Papel Papel del Saldo Contable
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdCta'} Cuenta Cuenta del Saldo Contable
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdOper'} Operacion Operación del Saldo Contable
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdSbop'} SubOperacion Suboperación del Saldo Contable
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdTope'} Tipo de Operacion Tipo de Operación del Saldo Contable
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdMod'} Modulo Operativo
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdFcon'} Fecha Contabilizacion
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdFval'} Fecha Valor
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdFvto'} Fecha Vencimiento
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdFulm'} Fecha Ulitmo Movimiento
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdPzo'} Plazo
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdSdoh'} Saldo Historico en Dolares
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdSegm'} Segmento de Cliente o Mercado
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdFunc'} Funcion
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdStat'} Estado
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdCc'} Centro de Costos
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdTit'} Titulo (1er modulo)
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdCap'} Capitulo (1er. modulo)
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdPlzo'} Plazo (1er. modulo)
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdGru'} Grupo (1er. modulo)
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdDbh'} 1=Debito, 2=Haber
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdImp'} Importe (Saldo)
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdEst'} Estado
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdPqtC'} Codigo de paquete
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdPqtF'} Fecha de Integracion
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdTTas'} Tipo de Tasa
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdTasa'} Tasa (Coeficiente)
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdSbcta'} SubCuenta
# {'manual': 'Manual Saldos Iniciales', 'bandeja': 'BNJ000', 'campo': 'BnjSdSdoD'} Saldo Deudor
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040PGC'} Empresa Bantotal Empresa Bantotal
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040BNJ'} Bandeja Bandeja
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040NRO'} Numero Tarjeta Numero Tarjeta
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040TIP'} Tipo de Tarjeta Interna Se deben corresponder con los parametrizados en la TDD015
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040Suc'} Sucursal Administrativa Sucursal donde se otorgó la Tarjeta
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040CtE'} Cuenta Empresa Bantotal Cuenta Cliente
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040THP'} País Tarjeta Habiente País de la Persona
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040THT'} Tipo Documento Tarjeta Habiente Tipo de Documento de la Persona
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040THD'} Documento Tarjeta Habiente Número de Documento de la Persona
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040CDo'} Código de Domicilio Código de Domicilio
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040Nom'} Nombre de Tarjeta Nombre de Tarjeta , no nula
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040Lin'} Cuarta Línea Cuarta Línea
# Información adicional, texto libre
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ0406Co'} Código de Tipo de Comisión Código de Tipo de Comisión
# Tabla TDD036
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040TCD'} Tipo de Cuenta de Debito Tipo de Cuenta de Costo(E.T), los valores posibles son:
# E -> Cuenta de la empresa
# T -> Cuenta titular
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040DSu'} Sucursal Cta. Débito Sucursal de  de Débito
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040DCD'} Cuenta de Cta de Debito Cuenta de  de Débito
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040DSC'} Sub Cuenta de Debito SubCuenta de  de Débito
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040DMo'} Módulo de Cta Debito Módulo de  de Débito
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040DMn'} Moneda de Cta de Debito Moneda de  de Débito
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040DPa'} Papel de Cta de Debito Papel de  de Débito
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040DTO'} Tipo de operación Cta Debito Tipo de operación de  de Débito
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040DOp'} Operación de Cta Debito Operación de  de Débito
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040FUU'} Fecha de Ultimo Uso Fecha de Ultimo Uso
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040FAL'} Fecha de Alta Fecha de Alta
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040PRC'} Marca de Procesado Ver descripción de estados en 1.4.2.
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040TTI'} Tarjeta Titular Numero de Tarjeta Titular, si BNJ040NRO es adicional
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040ADI'} Adicional? S = la tarjeta es adicional de , N = la tarjeta es titular
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040MCa'} Motivo de Cancelación Motivo de Cancelación
# Según tabla FTD13
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040LIM'} Código de Límite Código de Límite
# Tabla TDD026
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040Est'} Estado de la Tarjeta Se migra solo con valor en ‘AC’. Indica que la tarjeta esta activa.
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040AX1'} Correlativo Correlativo de registro
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040FBJ'} Fecha de Baja TD
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040TNV'} Tipo de Novedad
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040CSA'} Codigo de Situacion Actual
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040UAL'} Usuario Alta
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040UAP'} Usuario Aprobo Alta
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040IDT'} Identificador de Tarjeta
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040TPL'} Tipo de Plastico Tipo de Plastico
# Tabla TDD009 (TDD009IDP = 'TIPOS_PLASTICO')
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040EPL'} Estado del Plastico
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040SPL'} Sucursal Plastico
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040SDE'} Sucursal Destino
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040VIG'} Vigencia en Años
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040NR1'} Numero de Referencia 1
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040NR2'} Numero de Referencia 2
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040OEX'} Permite Operar en Extranjero
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040OIN'} Permite Operar en Internet
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040BON'} Porcentaje Bonificacion sobre Costo
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ040', 'campo': 'BNJ040BVT'} Vencimiento Bonificacion
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ041', 'campo': 'BNJ041PGC'} Empresa Empresa
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ041', 'campo': 'BNJ041BNJ'} Bandeja Bandeja
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ041', 'campo': 'BNJ041Nro'} Numero Tarjeta Numero Tarjeta
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ041', 'campo': 'BNJ041IDC'} Identificador de cuenta
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ041', 'campo': 'BNJ041IDT'} Identificador de tarjeta (Se genera de forma automatic al importer)
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ041', 'campo': 'BNJ041Suc'} Sucursal Sucursal de la Cta. Asociada
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ041', 'campo': 'BNJ041Cta'} Cuenta Cuenta de la Cta. Asociada
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ041', 'campo': 'BNJ041SCt'} SubCuenta SubCuenta de la Cta. Asociada
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ041', 'campo': 'BNJ041Mod'} Modulo Modulo de la Cta. Asociada
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ041', 'campo': 'BNJ041Mon'} Moneda Moneda de la Cta. Asociada
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ041', 'campo': 'BNJ041Pap'} Papel Papel de la Cta. Asociada
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ041', 'campo': 'BNJ041Top'} Tipo de Operación Tipo de Operación de la Cta. Asociada
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ041', 'campo': 'BNJ041Ope'} Operación Operación de la Cta. Asociada
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ041', 'campo': 'BNJ041emp'} Empresa Empresa
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ041', 'campo': ''} Estado de Cuenta No se utiliza
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ041', 'campo': ''} Tipo de Cuenta Corresponde a la clasificación de la cuenta, los valores posibles se obtienen desde la TDD009 (Filtrando por TDD009IDP = 'CLASIFICACION-CUENTAS')
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ041', 'campo': ''} Usuario ingresante
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ041', 'campo': ''} Fecha de autorizacion
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ041', 'campo': ''} Usuario autorizante
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ041', 'campo': 'BNJ041Cod'} Código de estado de cuentas No se utiliza
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ041', 'campo': 'BNJ041TiU'} Tipo de uso No se utiliza
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ041', 'campo': 'BNJ041CaC'} Categoria de cuenta No se utiliza
# {'manual': 'Manual Tarjetas de Débito', 'bandeja': 'BNJ041', 'campo': 'BNJ041Prc'} Estado de control Corresponde al estado de control. Ver descripción de estados en 1.4.3.

# %%
db_ret = Chroma(persist_directory="db_campos", embedding_function=OpenAIEmbeddings())
retriever = db_ret.as_retriever()

# %%
def parse_campos(pregunta):
    campos =  db_ret.similarity_search(pregunta,filter={"manual":manual},k=10)
    print(campos)
    string = ""
    for c in campos:
        md = c.metadata
        string += f'- Campo: {md["campo"]}. Descripción: {c.page_content}. Pertenece a la bandeja: {md["bandeja"]}. Es de tipo: {md["tipo"]} \n\n'
    return string



prompt = PromptTemplate(template=""" 
Sos un asistente de chat para el proceso de migración de Bantotal.
Se presenta una breve introducción sobre el proceso de migración:

<introduccion>
En el Sistema existen dos tipos de programas claramente diferenciados:
Programas de Control: son aquellos  que verifican que los datos que se pretenden grabar en las tablas sean aptos. Indican cada registro con un código de estado (si es válido o no).
Programas de Vuelco: son aquellos que toman la información controlada por los programas de Control, y la graban en las tablas.

Los programas de Control y de Vuelco actúan sobre determinados registros, que se identifican como pertenecientes a una Bandeja. Es decir, una Bandeja identifica a un conjunto de registros, que pueden pertenecer a una o más tablas y ser “vistas” de estas.

Las Bandejas se crean específicamente para cada cliente de acuerdo a sus necesidades. Se entiende que una Bandeja reúne un conjunto de operaciones de un mismo tipo de producto (por ejemplo: Cajas de Ahorro).

Unificando estos dos conceptos descritos, este Sistema contiene programas que procesan determinada información, que se denomina Bandeja.
</introduccion>


Se cuenta con las siguientes bandejas:
<bandejas>
{desc_bandejas}
</bandejas>                

Se tiene una lista de potenciales registros para guardar la información:
                        
<resgistros>
{campos}
</resgistros>

La información a guardar es:
información: {pregunta}
                        
Elegir cual o cuales de los resgistro o resgistros es adecuado para guardar esa información.
Luego explicar que información guarda la bandeja a la que pertenece el resgistro, y desarrollar sobre que significa el tipo del resgistro.
En caso que haya varios resgistros posibles, explicar la razon por la cual seleccionaste cada uno y decir cual es el más probable entre los elegidos.
""", input_variables=["pregunta","campos","desc_bandejas"])

# %%
manual = 'Manual Tarjetas de Débito'
desc_bandejas = get_desc_bandejas(manual)
pregunta = "Fecha de vencimiento de una tarjeta"
retriever = db_ret.as_retriever(filter={"manual":manual},k=10)

llm = ChatOpenAI(temperature=0.0)
chain = {"campos":itemgetter("pregunta") | RunnableLambda(parse_campos),"desc_bandejas":itemgetter("manual") | RunnableLambda(get_desc_bandejas), "pregunta":itemgetter("pregunta")} | prompt | llm | StrOutputParser()

# %%
print(chain.invoke({"pregunta":pregunta,"manual":manual}))
# Out:
# [Document(page_content='Identificador de Tarjeta ', metadata={'bandeja': 'BNJ040', 'campo': 'BNJ040IDT', 'manual': 'Manual Tarjetas de Débito', 'tipo': 'N ( 10.0 )'}), Document(page_content='Fecha de autorizacion ', metadata={'bandeja': 'BNJ041', 'campo': '', 'manual': 'Manual Tarjetas de Débito', 'tipo': 'D'}), Document(page_content='Vencimiento Bonificacion ', metadata={'bandeja': 'BNJ040', 'campo': 'BNJ040BVT', 'manual': 'Manual Tarjetas de Débito', 'tipo': 'D'}), Document(page_content='Fecha de Ultimo Uso Fecha de Ultimo Uso', metadata={'bandeja': 'BNJ040', 'campo': 'BNJ040FUU', 'manual': 'Manual Tarjetas de Débito', 'tipo': 'D'}), Document(page_content='Numero Tarjeta Numero Tarjeta', metadata={'bandeja': 'BNJ041', 'campo': 'BNJ041Nro', 'manual': 'Manual Tarjetas de Débito', 'tipo': 'C (19)'}), Document(page_content='Numero Tarjeta Numero Tarjeta', metadata={'bandeja': 'BNJ040', 'campo': 'BNJ040NRO', 'manual': 'Manual Tarjetas de Débito', 'tipo': 'C (19)'}), Document(page_content='Fecha de Baja TD ', metadata={'bandeja': 'BNJ040', 'campo': 'BNJ040FBJ', 'manual': 'Manual Tarjetas de Débito', 'tipo': 'D'}), Document(page_content='Vigencia en Años ', metadata={'bandeja': 'BNJ040', 'campo': 'BNJ040VIG', 'manual': 'Manual Tarjetas de Débito', 'tipo': 'N ( 2.0 )'}), Document(page_content='Fecha de Alta Fecha de Alta', metadata={'bandeja': 'BNJ040', 'campo': 'BNJ040FAL', 'manual': 'Manual Tarjetas de Débito', 'tipo': 'D'}), Document(page_content='Nombre de Tarjeta Nombre de Tarjeta , no nula', metadata={'bandeja': 'BNJ040', 'campo': 'BNJ040Nom', 'manual': 'Manual Tarjetas de Débito', 'tipo': 'C (24)'})]
# Para guardar la información de la Fecha de vencimiento de una tarjeta, los registros adecuados serían:
#
# - Campo: BNJ040BVT. Descripción: Vencimiento Bonificación. Pertenece a la bandeja: BNJ040. Es de tipo: D
#
# Este registro pertenece a la bandeja BNJ040, que almacena información de las tarjetas de débito, tanto de las titulares como de las adicionales. El tipo de registro es de tipo D, lo que indica que se trata de un campo de tipo fecha. Por lo tanto, este registro sería el más adecuado para guardar la información de la Fecha de vencimiento de una tarjeta, ya que está directamente relacionado con la información de vencimiento de la tarjeta en la bandeja correspondiente.
#
# En resumen, el registro BNJ040BVT sería el más probable y adecuado para guardar la información de la Fecha de vencimiento de una tarjeta en el proceso de migración de Bantotal.
