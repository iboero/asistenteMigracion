# %%
from langchain.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser, JsonOutputParser


from dotenv import load_dotenv
from pyprojroot import here
from langsmith import Client
from uuid import uuid4

import os
## INICIAR LANGSMITH Y API KEYS
dotenv_path = here() / ".env"
load_dotenv(dotenv_path=dotenv_path)


client = Client()

unique_id = uuid4().hex[0:8]
os.environ["LANGCHAIN_PROJECT"] = f"Debug - {unique_id}"





prompt_gen_resumen = PromptTemplate(template=""" 
Genera un resumen enfocado y detallado, limitado a aproximadamente 100 palabras, sobre la seccion {seccion} del {manual} de Bantotal, siguiendo estas directrices:

- Iniciar directamente con una descripción específica de los procesos, técnicas, o aspectos relevantes cubiertos en la sección, omitiendo cualquier introducción o mención general al manual.
- Incluir un breve resumen de las subsecciones, si están presentes, destacando sus contribuciones clave al tema principal.
- Proporcionar una descripción concisa de cualquier tabla incluida, enfocándose en su función y relevancia dentro del contexto de migración. Estas se incluyen como TABLA: [tabla]
El contenido a resumir está delimitado por triple comillas (''').
                                    
Contenido: ''' 
{contenido}                         
'''
Resumen de 100 palabras:
""",input_variables=["contenido","seccion","manual"])

# %%
import docx
import re
from langchain.docstore.document import Document
import os


import docx
import os



class tree():
    def __init__(self, section,level,manual):
        self.section = section
        self.childrens = []
        self.level = level
        self.resumen = ""
        self.content = ""
        self.manual = manual

    def add_child(self,child):  
        self.childrens.append(child)

    def print_index(self, numbering="", indent=0, index_string="",w_content=False):
        index_string += '\t' * indent + numbering + self.section+"\n"
        for i, child in enumerate(self.childrens, start=1):
            index_string = child.print_index(numbering + f"{i}.", indent + 1, index_string)
        return index_string

    def print_index_w_content(self, numbering="", indent=0, index_string=""):
        index_string += '\t' * indent + numbering + self.section + ':  '+ self.resumen +"\n"
        for i, child in enumerate(self.childrens, start=1):
            index_string = child.print_index_w_content(numbering + f"{i}.", indent + 1, index_string)
        return index_string

    def generar_resumenes_input(self):
        for i, child in enumerate(self.childrens, start=1):
            child_resumen = child.generar_resumenes_input()
        self.resumen = input(f"Manual: {self.manual}, Seccion: {self.section}")
        return self.resumen
    
    def generar_resumenes_AI(self,numbering=""):
        full_content = numbering + self.section + ": "+self.content + '\n'
        if len(self.childrens) != 0:
            full_content += '\n \n Resumen subsecciones: \n'
        for i, child in enumerate(self.childrens, start=1):
            child_resumen = child.generar_resumenes(numbering=numbering + f"{i}.")
            full_content += '\n' + numbering + f"{i} " + child.section + ": "+child.resumen + '\n'
        chain = prompt_gen_resumen | ChatOpenAI(temperature=0.0) | StrOutputParser()
        self.resumen = chain.invoke({"contenido":full_content,"seccion": numbering + self.section,"manual":self.manual})
        return self.resumen

    def lista_secc_y_desc(self, numbering=""):
        lista_sec = []
        lista_desc = []
        for i, child in enumerate(self.childrens, start=1):
            lista_sec_i, lista_desc_i = child.lista_secc_y_desc(numbering=numbering + f"{i}.")
            lista_sec += lista_sec_i
            lista_desc += lista_desc_i
        lista_sec.append(numbering + " " + self.section )
        lista_desc.append(self.resumen)
        return lista_sec, lista_desc

    def get_resumenes_y_content_list(self):
        lista_resumenes = []
        lista_content = []
        for i, child in enumerate(self.childrens, start=1):
            lista_resumenes_i, lista_content_i = child.get_resumenes_y_content_list()
            lista_resumenes += lista_resumenes_i
            lista_content += lista_content_i
        lista_resumenes.append(self.resumen)
        lista_content.append(self.content)
        return lista_resumenes, lista_content

class docx_loader():
    def __init__(self, docx_path):
        self.documents = []
        self.docx_path = docx_path
        self.manual = os.path.splitext(os.path.basename(docx_path))[0]
        self.contenido = tree(self.manual,0,self.manual) 

    def split_by_sections(self):
        docx_path = self.docx_path
        doc = docx.Document(docx_path)
        documents = []
        current_metadata = {}
        current_content = []
        level = 0
        # Obtener el título del documento a partir del nombre del archivo
        current_metadata['titulo'] = os.path.splitext(os.path.basename(docx_path))[0]

        for block in self.iter_block_items(doc):
            if isinstance(block, docx.text.paragraph.Paragraph):
                paragraph = block
                if paragraph.style.name.startswith('Heading') or paragraph.style.name.startswith('Titulo'):
                    # Guardar el documento actual si hay contenido
                    page_content = '\n'.join(current_content)
                    documents.append(Document(page_content=page_content, metadata=current_metadata.copy()))
                    self.add_contenido_a_nodo(current_metadata, level, page_content)
                    current_content = []

                    # Extraer nivel y texto del encabezado
                    level = int(float(paragraph.style.name.split(' ')[1]))
                    text = re.sub(r'^[\d.]+\s*', '', paragraph.text)
                    current_metadata[f's{level}'] = text
                    for i in range(level + 1, len(current_metadata) + 1):
                        current_metadata.pop(f's{i}', None)

                    # Añadir el título al árbol de contenido
                    if not text.strip() is "":
                        self.add_to_contenido(current_metadata, level)

                else:
                    if paragraph.text.strip() != '':
                        current_content.append(paragraph.text)

            elif isinstance(block, docx.table.Table):
                table = block
                texto_tabla = ""
                texto_tabla += 'TABLA: \n'
                for row in table.rows:
                    for cell in row.cells:
                        texto_tabla += self.clean_document(cell.text) + ' | '
                    texto_tabla += '\n'
                current_content.append(texto_tabla)

        # Asegurarse de añadir el último documento
        if current_content:
            page_content = '\n'.join(current_content)
            documents.append(Document(page_content=page_content, metadata=current_metadata.copy()))
        if os.path.splitext(os.path.basename(docx_path))[0] != "Manual Proceso de Migracion":
            content = self.contenido.print_index().replace("Manual", "Manual Migracion de")
            documents.insert(1,Document(page_content=content, metadata={"titulo":os.path.splitext(os.path.basename(docx_path))[0], "s1":"Contenido"}))
        else:
            documents.insert(1,Document(page_content=self.contenido.print_index(), metadata={"titulo":os.path.splitext(os.path.basename(docx_path))[0], "s1":"Contenido"}))
        return documents

    def add_to_contenido(self,  current_metadata, level):
        """
        Agrega un elemento al árbol de contenido.
        """
        current_node = self.contenido
        for i in range(1, level):
            for child in current_node.childrens:
                if current_metadata[f's{i}'] == child.section:
                    current_node = child
        new_node = tree(current_metadata[f's{level}'],level,self.manual)
        current_node.childrens.append(new_node)

    def add_contenido_a_nodo(self,  current_metadata, level,content):
        """
        Agrega un elemento al árbol de contenido.
        """
        current_node = self.contenido
        for i in range(1, level+1):
            for child in current_node.childrens:
                if current_metadata[f's{i}'] == child.section:
                    current_node = child
        current_node.content = content

    def iter_block_items(self, doc):
        """
        Genera un iterador de todos los elementos del cuerpo del documento, 
        incluyendo párrafos y tablas.
        """
        for item in doc.element.body:
            if isinstance(item, docx.oxml.text.paragraph.CT_P):
                yield docx.text.paragraph.Paragraph(item, doc._part)
            elif isinstance(item, docx.oxml.table.CT_Tbl):
                yield docx.table.Table(item, doc._part)

    def clean_document(self,document):
        cleaned_document = re.sub(r'\n+', '\n', document.replace("\r"," ").replace("\t"," ")).strip()
        cleaned_document = cleaned_document.replace("=", " ").replace("-", " ")
        cleaned_document = re.sub(r'\s+', ' ', cleaned_document).strip()
        cleaned_document = (" ").join(cleaned_document.split(" ")) #[:512]
        return cleaned_document
# Out:
# <>:110: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:110: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# C:\Users\iboero\AppData\Local\Temp\ipykernel_17524\2799280292.py:110: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if not text.strip() is "":

# %%
in_path = 'C:/Users/iboero/Chat_w_PDF/data/raw_docs/Migracion/'

# %%
# System imports
import os
import json
import dill as pkl


# Cargar documentos

trees = {}
docs = {}
resumenes = {}
for raiz, dirs, archivos in os.walk(in_path):
        for archivo in archivos:
            if archivo.endswith(".docx"):
                path_completo = os.path.join(raiz, archivo)
                loader = docx_loader(path_completo)
                manual = archivo[:-5]
                secciones = loader.split_by_sections()
                loader.contenido.generar_resumenes_input()
                resumenes[manual], docs[manual] = loader.contenido.get_resumenes_y_content_list()
                trees[manual] = loader.contenido



with open("resumenes.txt", "w", encoding="utf-8") as archivo:
    json.dump(resumenes, archivo, ensure_ascii=False)

with open("documentos.txt", "w", encoding="utf-8") as archivo:
    json.dump(docs, archivo, ensure_ascii=False)

filename = 'dict_arbol_secciones.pkl'
with open(filename, 'wb') as file:
    pkl.dump(trees, file)

# %%
def strip_seccion(tree):
    tree.section = tree.section.strip()
    for i, child in enumerate(tree.childrens, start=1):
        strip_seccion(child)
    return

# %%
for k in trees.keys():
    strip_seccion(trees[k])
    print(trees[k].print_index_w_content())
# Out:
# Manual Acuerdos de Sobregiro:
# 	1.Ciclo de Migraciones:  No tiene contenido, sirve para agrupar subsecciones hijas
# 		1.1.Introducción:  Explica brevemente el propósito de la migración de y los pasos generales involucrados, incluyendo la generación de estructuras en bandejas y el control de calidad de datos.
# 		1.2.Migraciones Previas:  Discute los requisitos de migraciones previas, como aquellos sistemas necesarios de migrar previamente.
# 			1.2.1.Migración de Saldos Iniciales:
# 			1.2.2.Migración de Clientes:
# 			1.2.3.Migración de Cuentas Vista:
# 		1.3.Generación de Estructuras de Bandejas:  Lista las diferentes bandejas que conforman el sistema y detalla sobre que tipo de información guarda cada bandeja y cual es su equivalente en el sistema bantotal.
# 			1.3.1.Parametrizaciones:
# 		1.4.Control de Calidad de Datos de Bandejas:  No tiene contenido, sirve para agrupar subsecciones hijas
# 			1.4.1.Programas de Control:  Lista los programas de control asociados a cada bandeja, que se utilizan para verifican la coherencia e integridad de la información generada.
# 			1.4.2.Estados de Control:  Explica los diferentes estados de control en los que se pueden encontrar los registros en las bandejas dentro del proceso de migración.
# 			1.4.3.Salidas de Proceso:  Detalla las salidas de proceso posibles tras el control de consistencia, listando los posibles codigos de error, su descripción y como solucionarlos.
# 			1.4.4.Programas de Vuelco a Bantotal:  Lista los programas de vuelco encargados de procesar registros que pasaron el control de coherencia e integridad.
# 		1.5.Secuencia de Ejecución:  Resume los pasos y programas involucrados en el control y vuelco de saldos iniciales.
# 	2.Diseño de Tablas de Bandejas:  No tiene contenido, sirve para agrupar subsecciones hijas
# 		2.1.Tabla BNJ002:  Lista los registros que se guardan en la tabla BNJ002, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.2.Tabla BNJ012:  Lista los registros que se guardan en la tabla BNJ012, detallando el codigo del registro, una descripción de este y su tipo.
# 	3.Transacciones de Migraciones:
# 		3.1.Alta de Acuerdo Tasa Fija:
# 			3.1.1.Productos Acuerdo Tasa Fija  predefinidos:
# 			3.1.2.Transacción Alta de Cuentas Corrientes  (módulo 499, transacción 31):
# 			3.1.3.Ajuste a  del Banco:
# 		3.2.Alta de Acuerdo Tasa Variable:
# 			3.2.1.Productos Acuerdo Tasa Variable predefinidos:
# 			3.2.2.Transacción Acuerdo Tasa Variable (módulo 499, transacción 32):
# 			3.2.3.Ajuste a  del Banco:
# 		3.3.Alta de Acuerdo Tasa Vigente:
# 			3.3.1.Productos Acuerdo Tasa Vigente Predefinidos:
# 			3.3.2.Transacción Acuerdo Tasa Vigente (módulo 499, transacción 34):
# 			3.3.3.Ajuste a  del Banco:
#
# Manual Chequeras:
# 	1.Ciclo de Migraciones:  No tiene contenido, sirve para agrupar subsecciones hijas
# 		1.1.Introducción:  Explica brevemente el propósito de la migración de y los pasos generales involucrados, incluyendo la generación de estructuras en bandejas y el control de calidad de datos.
# 		1.2.Requisitos Previos:  Discute los requisitos de migraciones previas, como aquellos sistemas necesarios de migrar previamente.
# 			1.2.1.Migración de Clientes:
# 			1.2.2.Migración de Cuentas Vista:
# 			1.2.3.Parametrización de productos CV (PRD001):
# 			1.2.4.Parametrización de Tipos de Chequeras:
# 			1.2.5.Parametrización de Motivos de Cheques de Gerencia:
# 			1.2.6.Parametrización de Numeración de Chequeras:
# 			1.2.7.Parametrización de Estado de Chequera Activa:
# 		1.3.Generación de Estructuras de Bandejas:  Lista las diferentes bandejas que conforman el sistema y detalla sobre que tipo de información guarda cada bandeja y cual es su equivalente en el sistema bantotal.
# 		1.4.Control de Calidad de Datos de Bandejas:  No tiene contenido, sirve para agrupar subsecciones hijas
# 			1.4.1.Programas de Control:  Lista los programas de control asociados a cada bandeja, que se utilizan para verifican la coherencia e integridad de la información generada.
# 			1.4.2.Estados de Control:  Explica los diferentes estados de control en los que se pueden encontrar los registros en las bandejas dentro del proceso de migración.
# 			1.4.3.Salidas de Proceso:  Detalla las salidas de proceso posibles tras el control de consistencia, listando los posibles codigos de error, su descripción y como solucionarlos.
# 			1.4.4.Programas de Vuelco a Bantotal:  Lista los programas de vuelco encargados de procesar registros que pasaron el control de coherencia e integridad.
# 	2.Diseño de Tablas de Bandejas:  No tiene contenido, sirve para agrupar subsecciones hijas
# 		2.1.Tabla BNJ003:  Lista los registros que se guardan en la tabla BNJ003, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.2.Tabla BNJ010:  Lista los registros que se guardan en la tabla BNJ010, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.3.Tabla BJCH03:  Lista los registros que se guardan en la tabla BJCH03, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.4.Tabla BNJ007:  Lista los registros que se guardan en la tabla BNJ007, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.5.Tabla BNJ222:  Lista los registros que se guardan en la tabla BNJ222, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.6.Tabla BNJ006:  Lista los registros que se guardan en la tabla BNJ006, detallando el codigo del registro, una descripción de este y su tipo.
# 	3.Transacciones de Migraciones:
#
# Manual Cuentas Vistas:
# 	1.Introducción:  Explica brevemente el propósito de la migración de y los pasos generales involucrados, incluyendo la generación de estructuras en bandejas y el control de calidad de datos.
# 	2.Ciclo de Migraciones:  No tiene contenido, sirve para agrupar subsecciones hijas
# 		2.1.Introducción:  Explica brevemente el propósito de la migración de y los pasos generales involucrados, incluyendo la generación de estructuras en bandejas y el control de calidad de datos.
# 		2.2.Migraciones Previas:  Discute los requisitos de migraciones previas, como aquellos sistemas necesarios de migrar previamente.
# 			2.2.1.Migración de Saldos Iniciales:
# 			2.2.2.Migración de Clientes:
# 			2.2.3.Parametrización de productos CV (PRD001):
# 			2.2.4.Generación de Estructuras de Bandejas:  Lista las diferentes bandejas que conforman el sistema y detalla sobre que tipo de información guarda cada bandeja y cual es su equivalente en el sistema bantotal.
# 		2.3.Control de Calidad de Datos de Bandejas:  No tiene contenido, sirve para agrupar subsecciones hijas
# 			2.3.1.Programas de Control:  Lista los programas de control asociados a cada bandeja, que se utilizan para verifican la coherencia e integridad de la información generada.
# 		2.4.Estados de Control:  Explica los diferentes estados de control en los que se pueden encontrar los registros en las bandejas dentro del proceso de migración.
# 			2.4.1.Salidas de Proceso:  Detalla las salidas de proceso posibles tras el control de consistencia, listando los posibles codigos de error, su descripción y como solucionarlos.
# 			2.4.2.Programas de Vuelco a Bantotal:  Lista los programas de vuelco encargados de procesar registros que pasaron el control de coherencia e integridad.
# 		2.5.Secuencia de Ejecución:  Resume los pasos y programas involucrados en el control y vuelco de saldos iniciales.
# 	3.Diseño de Tablas de Bandejas:  No tiene contenido, sirve para agrupar subsecciones hijas
# 		3.1.Tabla BNJ002:  Lista los registros que se guardan en la tabla BNJ002, detallando el codigo del registro, una descripción de este y su tipo.
# 		3.2.Tabla BJD211:  Lista los registros que se guardan en la tabla BJD211, detallando el codigo del registro, una descripción de este y su tipo.
# 		3.3.Tabla BNJ004:  Lista los registros que se guardan en la tabla BNJ004, detallando el codigo del registro, una descripción de este y su tipo.
# 		3.4.Tabla BJD016:  Lista los registros que se guardan en la tabla BJD016, detallando el codigo del registro, una descripción de este y su tipo.
# 	4.Transacciones de Migraciones:
#
# Manual Cuentas y Personas:
# 	1.Ciclo de Migraciones:  No tiene contenido, sirve para agrupar subsecciones hijas
# 		1.1.Introducción:  Explica brevemente el propósito de la migración de y los pasos generales involucrados, incluyendo la generación de estructuras en bandejas y el control de calidad de datos.
# 		1.2.Migraciones Previas:  Discute los requisitos de migraciones previas, como aquellos sistemas necesarios de migrar previamente.
# 		1.3.Generación de Estructuras de Bandejas:  Lista las diferentes bandejas que conforman el sistema y detalla sobre que tipo de información guarda cada bandeja y cual es su equivalente en el sistema bantotal.
# 		1.4.Control de Calidad de Datos de Bandejas:  No tiene contenido, sirve para agrupar subsecciones hijas
# 			1.4.1.Programas de Control:  Lista los programas de control asociados a cada bandeja, que se utilizan para verifican la coherencia e integridad de la información generada.
# 			1.4.2.Estados de Control:  Explica los diferentes estados de control en los que se pueden encontrar los registros en las bandejas dentro del proceso de migración.
# 			1.4.3.Salidas de Proceso:  Detalla las salidas de proceso posibles tras el control de consistencia, listando los posibles codigos de error, su descripción y como solucionarlos.
# 			1.4.4.Programas de Vuelco a Bantotal:  Lista los programas de vuelco encargados de procesar registros que pasaron el control de coherencia e integridad.
# 		1.5.Secuencia de Ejecución:  Resume los pasos y programas involucrados en el control y vuelco de saldos iniciales.
# 	2.Diseño de Tablas de Bandejas:  No tiene contenido, sirve para agrupar subsecciones hijas
# 		2.1.Tabla BJD001:  Lista los registros que se guardan en la tabla BJD001, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.2.Tabla BJD002:  Lista los registros que se guardan en la tabla BJD002, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.3.Tabla BJD003:  Lista los registros que se guardan en la tabla BJD003, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.4.Tabla BJD004:  Lista los registros que se guardan en la tabla VJD004, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.5.Tabla BNGC13:  Lista los registros que se guardan en la tabla BNGC13, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.6.Tabla BJR005:  Lista los registros que se guardan en la tabla BJ4005, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.7.Tabla BJD201:  Lista los registros que se guardan en la tabla BJD201, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.8.Tabla BJE101:  Lista los registros que se guardan en la tabla BJE101, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.9.Tabla BJE102:  Lista los registros que se guardan en la tabla BJE102, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.10.Tabla BJE103:  Lista los registros que se guardan en la tabla BJE103, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.11.Tabla BJR001:  Lista los registros que se guardan en la tabla BJR001, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.12.Tabla BJR002:  Lista los registros que se guardan en la tabla BJR002, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.13.Tabla BJR003:  Lista los registros que se guardan en la tabla BJR003, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.14.Tabla BJR004:  Lista los registros que se guardan en la tabla BJR004, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.15.Tabla BJX001:  Lista los registros que se guardan en la tabla BJX001, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.16.Tabla BJD008:  Lista los registros que se guardan en la tabla BJD008, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.17.Tabla BJE108:  Lista los registros que se guardan en la tabla BJE108, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.18.Tabla BJR008:  Lista los registros que se guardan en la tabla BJR008, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.19.Tabla BJD009:  Lista los registros que se guardan en la tabla BJD009, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.20.Tabla BJX008:  Lista los registros que se guardan en la tabla BJX008, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.21.Tabla BNJTI1:  Lista los registros que se guardan en la tabla CNJTI1, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.22.Tabla BNJTI2:  Lista los registros que se guardan en la tabla BNJTI2, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.23.Tabla BNGC60:  Lista los registros que se guardan en la tabla BNGC60, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.24.Tabla BNGC11:  Lista los registros que se guardan en la tabla BNGC11, detallando el codigo del registro, una descripción de este y su tipo.
# 	3.Transacciones de Migraciones:
#
# Manual Depósitos:
# 	1.Ciclo de Migraciones:  No tiene contenido, sirve para agrupar subsecciones hijas
# 		1.1.Introducción:  Explica brevemente el propósito de la migración de y los pasos generales involucrados, incluyendo la generación de estructuras en bandejas y el control de calidad de datos.
# 		1.2.Requisitos Previos:  Discute los requisitos de migraciones previas, como aquellos sistemas necesarios de migrar previamente.
# 			1.2.1.Migración de Saldos Iniciales:
# 			1.2.2.Migración de Clientes:
# 			1.2.3.Migración de Cuentas Vista:
# 			1.2.4.Clase de Tasa para Tasa de Corte:
# 			1.2.5.Plazos Válidos de DPF:
# 			1.2.6.Tolerancia para Control de Intereses:
# 			1.2.7.Valores por Defecto:
# 			1.2.8.Migración sin Históricos.:
# 			1.2.9.Códigos de Relaciones para Endosos y Fraccionamientos:
# 		1.3.Generación de Estructuras de Bandejas:  Lista las diferentes bandejas que conforman el sistema y detalla sobre que tipo de información guarda cada bandeja y cual es su equivalente en el sistema bantotal.
# 		1.4.Control de Calidad de Datos de Bandejas:  No tiene contenido, sirve para agrupar subsecciones hijas
# 			1.4.1.Programas de Control:  Lista los programas de control asociados a cada bandeja, que se utilizan para verifican la coherencia e integridad de la información generada.
# 			1.4.2.Estados de Control:  Explica los diferentes estados de control en los que se pueden encontrar los registros en las bandejas dentro del proceso de migración.
# 			1.4.3.Salidas de Proceso:  Detalla las salidas de proceso posibles tras el control de consistencia, listando los posibles codigos de error, su descripción y como solucionarlos.
# 			1.4.4.Programas de Vuelco a Bantotal:  Lista los programas de vuelco encargados de procesar registros que pasaron el control de coherencia e integridad.
# 		1.5.Secuencia de Ejecución:  Resume los pasos y programas involucrados en el control y vuelco de saldos iniciales.
# 	2.Diseño de Tablas de Bandejas:  No tiene contenido, sirve para agrupar subsecciones hijas
# 		2.1.Tabla BNJ002:  Lista los registros que se guardan en la tabla BNJ002, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.2.Tabla BNJ012:  Lista los registros que se guardan en la tabla BNJ012, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.3.Tabla BNJ601:  Lista los registros que se guardan en la tabla BNJ601, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.4.Tabla BNJ602:  Lista los registros que se guardan en la tabla BNJ602, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.5.Tabla BJR111:  Lista los registros que se guardan en la tabla BJR111, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.6.Tabla BJR011:  Lista los registros que se guardan en la tabla BJR011, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.7.Tabla BNJ016:  Lista los registros que se guardan en la tabla BNJ016, detallando el codigo del registro, una descripción de este y su tipo.
# 	3.Transacciones de Migraciones:
#
# Manual Descuentos:
# 	1.Ciclo de Migraciones:  No tiene contenido, sirve para agrupar subsecciones hijas
# 		1.1.Introducción:  Explica brevemente el propósito de la migración de y los pasos generales involucrados, incluyendo la generación de estructuras en bandejas y el control de calidad de datos.
# 		1.2.Migraciones Previas y otras Consideraciones:  Discute los requisitos de migraciones previas, como aquellos sistemas necesarios de migrar previamente.
# 			1.2.1.Migración de Saldos Iniciales:
# 			1.2.2.Migración de Clientes:
# 			1.2.3.Tolerancia:
# 			1.2.4.Valores por Defecto:
# 		1.3.Generación de Estructuras de Bandejas:  Lista las diferentes bandejas que conforman el sistema y detalla sobre que tipo de información guarda cada bandeja y cual es su equivalente en el sistema bantotal.
# 		1.4.Control de Calidad de Datos de Bandejas:  No tiene contenido, sirve para agrupar subsecciones hijas
# 			1.4.1.Programas de Control:  Lista los programas de control asociados a cada bandeja, que se utilizan para verifican la coherencia e integridad de la información generada.
# 			1.4.2.Estados de Control:  Explica los diferentes estados de control en los que se pueden encontrar los registros en las bandejas dentro del proceso de migración.
# 			1.4.3.Salidas de Proceso:  Detalla las salidas de proceso posibles tras el control de consistencia, listando los posibles codigos de error, su descripción y como solucionarlos.
# 			1.4.4.Programas de Vuelco a Bantotal:  Lista los programas de vuelco encargados de procesar registros que pasaron el control de coherencia e integridad.
# 			1.4.5.Programas de Control:  Lista los programas de control asociados a cada bandeja, que se utilizan para verifican la coherencia e integridad de la información generada.
# 			1.4.6.Estados de Control:  Explica los diferentes estados de control en los que se pueden encontrar los registros en las bandejas dentro del proceso de migración.
# 			1.4.7.Salidas de Proceso:  Detalla las salidas de proceso posibles tras el control de consistencia, listando los posibles codigos de error, su descripción y como solucionarlos.
# 			1.4.8.Programas de Vuelco a Bantotal:  Lista los programas de vuelco encargados de procesar registros que pasaron el control de coherencia e integridad.
# 		1.5.Secuencia de Ejecución:  Resume los pasos y programas involucrados en el control y vuelco de saldos iniciales.
# 	2.Diseño de Tablas de Bandejas:  No tiene contenido, sirve para agrupar subsecciones hijas
# 		2.1.Tabla BNJ002:  Lista los registros que se guardan en la tabla BNJ002, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.2.Tabla BNJ601:  Lista los registros que se guardan en la tabla BNJ601, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.3.Tabla BJR601:  Lista los registros que se guardan en la tabla BJR601, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.4.Tabla BJE012:  Lista los registros que se guardan en la tabla BJE012, detallando el codigo del registro, una descripción de este y su tipo.
# 	3.Transacciones de Migraciones:
# 		3.1.Migración Descuento Valor Nominal:
# 			3.1.1.Productos Descuento Valor Nominal Predefinidos:
# 			3.1.2.Transacción Migración Descuento Valor Nominal (módulo 499, transacción 190):
# 			3.1.3.Ajuste a la Operativa del Banco:
# 		3.2.Migración Descuento Valor Presente:
# 			3.2.1.Productos Descuento Valor Presente predefinidos:
# 			3.2.2.Transacción Migración Descuento Valor Presente (módulo 499-transacción 200):
# 			3.2.3.Ajuste a la operativa del Banco:
#
# Manual Facultades:
# 	1.Ciclo de Migraciones:  No tiene contenido, sirve para agrupar subsecciones hijas
# 		1.1.Introducción:  Explica brevemente el propósito de la migración de y los pasos generales involucrados, incluyendo la generación de estructuras en bandejas y el control de calidad de datos.
# 		1.2.Migraciones Previas:  Discute los requisitos de migraciones previas, como aquellos sistemas necesarios de migrar previamente.
# 			1.2.1.Migración de Personas y cuentas:
# 		1.3.Generación de Estructuras de Bandejas:  Lista las diferentes bandejas que conforman el sistema y detalla sobre que tipo de información guarda cada bandeja y cual es su equivalente en el sistema bantotal.
# 		1.4.Control de Calidad de Datos de Bandejas:  No tiene contenido, sirve para agrupar subsecciones hijas
# 			1.4.1.Programas de Control:  Lista los programas de control asociados a cada bandeja, que se utilizan para verifican la coherencia e integridad de la información generada.
# 			1.4.2.Estados de Control:  Explica los diferentes estados de control en los que se pueden encontrar los registros en las bandejas dentro del proceso de migración.
# 			1.4.3.Salidas de Proceso:  Detalla las salidas de proceso posibles tras el control de consistencia, listando los posibles codigos de error, su descripción y como solucionarlos.
# 			1.4.4.Programas de Vuelco a Bantotal:  Lista los programas de vuelco encargados de procesar registros que pasaron el control de coherencia e integridad.
# 		1.5.Secuencia de Ejecución:  Resume los pasos y programas involucrados en el control y vuelco de saldos iniciales.
# 	2.Diseño de Tablas de Bandejas:  No tiene contenido, sirve para agrupar subsecciones hijas
# 		2.1.Tabla BJF001 Facultades por cuentas:  Lista los registros que se guardan en la tabla BJF001, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.2.Tabla BJF002:  Lista los registros que se guardan en la tabla BJF002, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.3.Tabla BJF003 Facultades por cuentas::  Lista los registros que se guardan en la tabla BJF003, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.4.Tabla BJF004 Personas integrantes de Grupos titulares de Facultades por Cuenta-Cliente PF::  Lista los registros que se guardan en la tabla BJF004, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.5.Tabla BJF005 Facultades por operación::  Lista los registros que se guardan en la tabla BJF005, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.6.Tabla BJF006 Operación por grupos:  Lista los registros que se guardan en la tabla BJF006, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.7.Tabla BJF007 Facultades por Operación (Categoría):  Lista los registros que se guardan en la tabla BJF007, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.8.Tabla BJF008 Personas integrantes de Grupos titulares de Facultades por Operación (producto) PF Almacena información relativa a las facultades por Cuenta y categorías:  Lista los registros que se guardan en la tabla BJF008, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.9.Tabla BJF009 Facultades por Operación (Normativa):  Lista los registros que se guardan en la tabla BJF009, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.10.Tabla BJF010 Facultades Operación/Persona-Categoría (Por Facultad):  Lista los registros que se guardan en la tabla BJF0010, detallando el codigo del registro, una descripción de este y su tipo.
# 	3.Transacciones de Migraciones:
#
# Manual Garantías:
# 	1.Ciclo de Migraciones:  No tiene contenido, sirve para agrupar subsecciones hijas
# 		1.1.Introducción:  Explica brevemente el propósito de la migración de y los pasos generales involucrados, incluyendo la generación de estructuras en bandejas y el control de calidad de datos.
# 		1.2.Migraciones Previas:  Discute los requisitos de migraciones previas, como aquellos sistemas necesarios de migrar previamente.
# 			1.2.1.Migración de Saldos Iniciales:
# 			1.2.2.Migración de Clientes:
# 		1.3.Generación de Estructuras de Bandejas:  Lista las diferentes bandejas que conforman el sistema y detalla sobre que tipo de información guarda cada bandeja y cual es su equivalente en el sistema bantotal.
# 		1.4.Control de Calidad de Datos de Bandejas:  No tiene contenido, sirve para agrupar subsecciones hijas
# 			1.4.1.Programas de Control:  Lista los programas de control asociados a cada bandeja, que se utilizan para verifican la coherencia e integridad de la información generada.
# 			1.4.2.Estados de Control:  Explica los diferentes estados de control en los que se pueden encontrar los registros en las bandejas dentro del proceso de migración.
# 			1.4.3.Salidas de Proceso:  Detalla las salidas de proceso posibles tras el control de consistencia, listando los posibles codigos de error, su descripción y como solucionarlos.
# 			1.4.4.Programas de Vuelco a Bantotal:  Lista los programas de vuelco encargados de procesar registros que pasaron el control de coherencia e integridad.
# 		1.5.Secuencia de Ejecución:  Resume los pasos y programas involucrados en el control y vuelco de saldos iniciales.
# 	2.Diseño de Tablas de Bandejas:  No tiene contenido, sirve para agrupar subsecciones hijas
# 		2.1.Tabla BNJ002:  Lista los registros que se guardan en la tabla BNJ002, detallando el codigo del registro, una descripción de este y su tipo.
# 	3.Transacciones de Migraciones:
# 		3.1.Migración Garantías Recibidas:
# 			3.1.1.Productos Garantías Recibidas Predefinidos:
# 			3.1.2.Transacción Migración Garantías Recibidas (módulo 499, transacción 210):
# 			3.1.3.Ajuste a la Operativa del Banco:
#
# Manual Líneas de Crédito:
# 	1.Ciclo de Migraciones:  No tiene contenido, sirve para agrupar subsecciones hijas
# 		1.1.Introducción:  Explica brevemente el propósito de la migración de y los pasos generales involucrados, incluyendo la generación de estructuras en bandejas y el control de calidad de datos.
# 		1.2.Migraciones Previas:  Discute los requisitos de migraciones previas, como aquellos sistemas necesarios de migrar previamente.
# 			1.2.1.Migración de Saldos Iniciales:
# 			1.2.2.Migración de Clientes:
# 		1.3.Generación de Estructuras de Bandejas:  Lista las diferentes bandejas que conforman el sistema y detalla sobre que tipo de información guarda cada bandeja y cual es su equivalente en el sistema bantotal.
# 		1.4.Control de Calidad de Datos de Bandejas:  No tiene contenido, sirve para agrupar subsecciones hijas
# 			1.4.1.Programas de Control:  Lista los programas de control asociados a cada bandeja, que se utilizan para verifican la coherencia e integridad de la información generada.
# 			1.4.2.Estados de Control:  Explica los diferentes estados de control en los que se pueden encontrar los registros en las bandejas dentro del proceso de migración.
# 			1.4.3.Salidas de Proceso:  Detalla las salidas de proceso posibles tras el control de consistencia, listando los posibles codigos de error, su descripción y como solucionarlos.
# 			1.4.4.Programas de Vuelco a Bantotal:  Lista los programas de vuelco encargados de procesar registros que pasaron el control de coherencia e integridad.
# 		1.5.Secuencia de Ejecución:  Resume los pasos y programas involucrados en el control y vuelco de saldos iniciales.
# 	2.Diseño de Tablas de Bandejas:  No tiene contenido, sirve para agrupar subsecciones hijas
# 		2.1.Tabla BNJ002:  Lista los registros que se guardan en la tabla BNJ002, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.2.Tabla BJR011:  Lista los registros que se guardan en la tabla BJR011, detallando el codigo del registro, una descripción de este y su tipo.
# 	3.Transacciones de Migraciones:
# 		3.1.Migración Alta de Líneas de Crédito:
# 			3.1.1.Productos de Líneas de Crédito Predefinidos:
# 			3.1.2.Alta de Líneas de Crédito (módulo 499, transacción 90):
# 			3.1.3.Ajuste a la Operativa  del Banco:
# 		3.2.Comentarios Adicionales:
#
# Manual Microfinanzas:
# 	1.Ciclo de Migraciones:  No tiene contenido, sirve para agrupar subsecciones hijas
# 		1.1.Introducción:  Explica brevemente el propósito de la migración de y los pasos generales involucrados, incluyendo la generación de estructuras en bandejas y el control de calidad de datos.
# 		1.2.Migraciones Previas:  Discute los requisitos de migraciones previas, como aquellos sistemas necesarios de migrar previamente.
# 			1.2.1.Migración de Saldos Iniciales:
# 			1.2.2.Migración de Clientes:
# 			1.2.3.Migración de Cuentas Vistas:
# 			1.2.4.Migración de Activas:
# 		1.3.Generación de Estructuras de Bandejas:  Lista las diferentes bandejas que conforman el sistema y detalla sobre que tipo de información guarda cada bandeja y cual es su equivalente en el sistema bantotal.
# 		1.4.Control de Calidad de Datos de Bandejas:  No tiene contenido, sirve para agrupar subsecciones hijas
# 			1.4.1.Programas de Control:  Lista los programas de control asociados a cada bandeja, que se utilizan para verifican la coherencia e integridad de la información generada.
# 			1.4.2.Estados de Control:  Explica los diferentes estados de control en los que se pueden encontrar los registros en las bandejas dentro del proceso de migración.
# 			1.4.3.Programas de Vuelco a Bantotal:  Lista los programas de vuelco encargados de procesar registros que pasaron el control de coherencia e integridad.
# 		1.5.Secuencia de Ejecución:  Resume los pasos y programas involucrados en el control y vuelco de saldos iniciales.
# 	2.Diseño de Tablas de Bandejas:  No tiene contenido, sirve para agrupar subsecciones hijas
# 		2.1.Tabla BNG001:  Lista los registros que se guardan en la tabla BNG001, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.2.Tabla BNG003:  Lista los registros que se guardan en la tabla BNG003, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.3.Tabla BNG102:  Lista los registros que se guardan en la tabla BNG102, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.4.Tabla BNG103:  Lista los registros que se guardan en la tabla BNG103, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.5.Tabla BNGC11:  Lista los registros que se guardan en la tabla BNGC11, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.6.Tabla BNGC13:  Lista los registros que se guardan en la tabla BNGC13, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.7.Tabla BNGC60:  Lista los registros que se guardan en la tabla BNGC60, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.8.Tabla BNG023:  Lista los registros que se guardan en la tabla BNG023, detallando el codigo del registro, una descripción de este y su tipo.
#
# Manual Préstamos:
# 	1.Ciclo de Migraciones:  No tiene contenido, sirve para agrupar subsecciones hijas
# 		1.1.Introducción:  Explica brevemente el propósito de la migración de y los pasos generales involucrados, incluyendo la generación de estructuras en bandejas y el control de calidad de datos.
# 		1.2.Migraciones Previas y otros Requerimientos:  Discute los requisitos de migraciones previas, como aquellos sistemas necesarios de migrar previamente.
# 			1.2.1.Migración de Saldos Iniciales:
# 			1.2.2.Migración de Clientes:
# 			1.2.3.Migración de Cuentas Vista:
# 			1.2.4.Migración de Líneas de Crédito:
# 			1.2.5.Información Requerida por Tablas de Parámetros:
# 			1.2.6.Tolerancias:
# 			1.2.7.Valores por Defecto:
# 			1.2.8.Migración sin Historia:
# 			1.2.9.Control de Orden de Pago de Cuotas:
# 			1.2.10.Evento Cambio de Tasa No Obligatorio para Tasa Revisable:
# 			1.2.11.Opción para Líneas de Crédito Obligatorias:
# 			1.2.12.Importes adicionales del Préstamo:
# 		1.3.Generación de Estructuras de Bandejas:  Lista las diferentes bandejas que conforman el sistema y detalla sobre que tipo de información guarda cada bandeja y cual es su equivalente en el sistema bantotal.
# 		1.4.Control de Calidad de Datos de Bandejas:  No tiene contenido, sirve para agrupar subsecciones hijas
# 			1.4.1.Programas de Control:  Lista los programas de control asociados a cada bandeja, que se utilizan para verifican la coherencia e integridad de la información generada.
# 			1.4.2.Estados de Control:  Explica los diferentes estados de control en los que se pueden encontrar los registros en las bandejas dentro del proceso de migración.
# 			1.4.3.Salidas de Proceso:  Detalla las salidas de proceso posibles tras el control de consistencia, listando los posibles codigos de error, su descripción y como solucionarlos.
# 			1.4.4.Programas de Vuelco a Bantotal:  Lista los programas de vuelco encargados de procesar registros que pasaron el control de coherencia e integridad.
# 		1.5.Secuencia de Ejecución:  Resume los pasos y programas involucrados en el control y vuelco de saldos iniciales.
# 	2.Diseño de Tablas de Bandejas:  No tiene contenido, sirve para agrupar subsecciones hijas
# 		2.1.Tabla BNJ002:  Lista los registros que se guardan en la tabla BNJ002, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.2.Tabla BNJ012:  Lista los registros que se guardan en la tabla BNJ012, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.3.Tabla BNJ601:  Lista los registros que se guardan en la tabla BNJ601, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.4.Tabla BNJ602:  Lista los registros que se guardan en la tabla BNJ602, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.5.Tabla BJR601:  Lista los registros que se guardan en la tabla BJR601, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.6.Tabla BJR011:  Lista los registros que se guardan en la tabla BJR011, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.7.Tabla BNJ009:  Lista los registros que se guardan en la tabla BNJ009, detallando el codigo del registro, una descripción de este y su tipo.
# 	3.Transacciones de Migraciones:
# 		3.1.Esquema Básico:
# 		3.2.Comentarios Adicionales:
#
# Manual Saldos Iniciales:
# 	1.Introducción:  Explica brevemente el propósito de la migración de y los pasos generales involucrados, incluyendo la generación de estructuras en bandejas y el control de calidad de datos.
# 	2.Ciclo de Migraciones:  No tiene contenido, sirve para agrupar subsecciones hijas
# 		2.1.Introducción:
# 			2.1.1.Consideraciones:  Detalla algunas consideraciones específicas a tener en cuenta.
# 		2.2.Migraciones Previas:  Discute los requisitos de migraciones previas, como aquellos sistemas necesarios de migrar previamente.
# 		2.3.Generación de Estructuras de Bandejas:  Lista las diferentes bandejas que conforman el sistema y detalla sobre que tipo de información guarda cada bandeja y cual es su equivalente en el sistema bantotal.
# 		2.4.Control de Calidad de Datos de Bandejas:  No tiene contenido, sirve para agrupar subsecciones hijas
# 			2.4.1.Programas de Control:  Lista los programas de control asociados a cada bandeja, que se utilizan para verifican la coherencia e integridad de la información generada.
# 			2.4.2.Estados de Control:  Explica los diferentes estados de control en los que se pueden encontrar los registros en las bandejas dentro del proceso de migración.
# 			2.4.3.Salidas de Proceso:  Detalla las salidas de proceso posibles tras el control de consistencia, listando los posibles codigos de error, su descripción y como solucionarlos.
# 			2.4.4.Programas de Vuelco a Bantotal:  Lista los programas de vuelco encargados de procesar registros que pasaron el control de coherencia e integridad.
# 			2.4.5.Salidas de Proceso:  Detalla las salidas de proceso posibles tras el vuelco, listando los posibles codigos de error, su descripción y como solucionarlos.
# 			2.4.6.Parametrizaciones Requeridas:
# 			2.4.7.Procesos posteriores.:
# 		2.5.Secuencia de Ejecución:  Resume los pasos y programas involucrados en el control y vuelco de saldos iniciales.
# 	3.Diseño de Tablas de Bandejas:  No tiene contenido, sirve para agrupar subsecciones hijas
# 		3.1.Tabla BNJ000:  Lista los registros que se guardan en la tabla BNJ000, detallando el codigo del registro, una descripción de este y su tipo.
# 	4.Transacciones de Migraciones:
#
# Manual Tarjetas de Débito:
# 	1.Ciclo de Migraciones:
# 		1.1.Introducción:  Explica brevemente el propósito de la migración de y los pasos generales involucrados, incluyendo la generación de estructuras en bandejas y el control de calidad de datos.
# 		1.2.Migraciones Previas:  Discute los requisitos de migraciones previas, como aquellos sistemas necesarios de migrar previamente.
# 			1.2.1.Migración de Clientes:
# 			1.2.2.Migración de Cuentas Vista:
# 		1.3.Generación de Estructuras de Bandejas:  Lista las diferentes bandejas que conforman el sistema y detalla sobre que tipo de información guarda cada bandeja y cual es su equivalente en el sistema bantotal.
# 		1.4.Control de Calidad de Datos de Bandejas:  No tiene contenido, sirve para agrupar subsecciones hijas
# 			1.4.1.Programas de Control:  Lista los programas de control asociados a cada bandeja, que se utilizan para verifican la coherencia e integridad de la información generada.
# 			1.4.2.Programas de Vuelco:  Lista los programas de vuelco encargados de procesar registros que pasaron el control de coherencia e integridad.
# 			1.4.3.Estados de Control:  Explica los diferentes estados de control en los que se pueden encontrar los registros en las bandejas dentro del proceso de migración.
# 			1.4.4.Salidas de Proceso:  Detalla las salidas de proceso posibles tras el control de consistencia, listando los posibles codigos de error, su descripción y como solucionarlos.
# 	2.Diseño de Tablas de Bandejas:  No tiene contenido, sirve para agrupar subsecciones hijas
# 		2.1.Tabla BNJ040:  Lista los registros que se guardan en la tabla BNJ040, detallando el codigo del registro, una descripción de este y su tipo.
# 		2.2.Tabla BNJ041:  Lista los registros que se guardan en la tabla BNJ041, detallando el codigo del registro, una descripción de este y su tipo.

# %%
import dill as pkl
filename = 'dict_arbol_secciones.pkl'
with open(filename, 'rb') as file:
    trees = pkl.load(file)

# %%
from langchain.prompts import PromptTemplate

prompt_rag = PromptTemplate(template=""" 
Sos un asistente en el sistema de migración de Bantotal. 
Dado el siguiente contenido, responder a la pregunta. Responder de forma amplia, ahondando en la mayor cantidad de detalles, pero SIN INVENTAR INFORMACIÓN. Toda la información debe ser recuperada del contenido. 
<contenido>
{contenido}
</contenido>

pregunta: {pregunta}

""", input_variables=["pregunta", "secciones"])

prompt_seccion = PromptTemplate(template=""" 
Sos un asistente en el sistema de migración de Bantotal. 
Debes ayudar al usuario a elegir cual de las secciones es la más apropiada para encontrar la respuesta a una pregunta.

El indice con las secciones es el siguiente:
{secciones}

Y la pregunta es: {pregunta}

Responder UNICAMENTE con un json blob con dos keys "nombre_seccion" y "numero_seccion", donde se encuentra el nombre y el numero (x.x.x) de la seccion más probable para responder la pregunta.

""", input_variables=["pregunta", "secciones"])

# %%
from operator import itemgetter
from langchain_core.runnables import RunnableLambda


def content_from_section(dicto):
    nro_seccion = dicto["seccion"]["numero_seccion"]
    manual = dicto["manual"]
    num = nro_seccion.split('.')
    seed = trees[manual]
    for x  in num:
        seed = seed.childrens[int(x)-1]
    content = f"Seccion {nro_seccion}: {seed.section} \n\n {seed.content} + \n\n"
    for child,idx in enumerate(seed.childrens):
        content += f"Seccion {nro_seccion}.{idx+1}: {child.section} \n\n {child.content} + \n\n"
    return content

def get_indice(manual):
    return trees[manual].print_index_w_content()

manual = 'Manual Chequeras'
pregunta = "Que campos tiene la bandeja BNJ006?"

chain_get_section = {"pregunta":itemgetter("pregunta"),"secciones": itemgetter("manual") | RunnableLambda(get_indice)} | prompt_seccion | ChatOpenAI(temperature=0.0) | JsonOutputParser()

chain_get_answer = {"pregunta": itemgetter("pregunta"), "contenido": {"seccion":chain_get_section, "manual": itemgetter("manual")} | RunnableLambda(content_from_section)} | prompt_rag | ChatOpenAI(temperature=0.0) | StrOutputParser()

res  = chain_get_answer.invoke({"pregunta":pregunta,"manual":manual})

res
# Out:
# 'La bandeja BNJ006 tiene los siguientes campos:\n- Empresa (BcleEmp)\n- Bandeja (BcleBnd)\n- Módulo (BcleMod)\n- Sucursal (BcleSuc)\n- Moneda (BcleMda)\n- Papel (BclePap)\n- Cuenta Cliente (BcleCta)\n- Operación (BcleOpe)\n- Sub Operación (BcleSub)\n- Tipo de Operación (BcleTOp)\n- Fecha (BclE1Fch)\n- Hora (Bcle1Hra)\n- Producto (Bcle1Prd)\n- Boleta (Bcle1Bol)\n- Cheque (Bcle1Chq)\n- Banco (Bcle1Bco)\n- Sucursal del Banco (Bcle1BSuc)\n- Código Postal (Bcle1CP)\n- Cuenta del Librador (Bcle1CtaL)\n- Plaza (Bcle1Pza)\n- Plazo (Bcle1Pzo)\n- Tipo de Cheque (Bcle1TChq)\n- Importe (Bcle1Imp)\n- Estado (Bcle1Est)\n- Moneda del Cheque (Bcle1Mda)\n- Motivo del Vencimiento (Bcle1MtVto)\n- Estado en Proceso de Migracion (Bcle1MEst)'

# %%
for chunk in chain_get_answer.stream({"pregunta":pregunta,"manual":manual}):
    print(chunk)
# Out:
# La
#  bande
# ja
#  BN
# J
# 006
#  tiene
#  los
#  siguientes
#  campos
# :
#
# -
#  Empresa
#  (
# B
# cle
# Emp
# )
#
# -
#  Band
# e
# ja
#  (
# B
# cle
# B
# nd
# )
#
# -
#  M
# ód
# ulo
#  (
# B
# cle
# Mod
# )
#
# -
#  Suc
# ursal
#  (
# B
# cle
# Suc
# )
#
# -
#  Mon
# eda
#  (
# B
# cle
# M
# da
# )
#
# -
#  Pap
# el
#  (
# B
# cle
# P
# ap
# )
#
# -
#  C
# uenta
#  Cliente
#  (
# B
# cle
# C
# ta
# )
#
# -
#  Oper
# ación
#  (
# B
# cle
# O
# pe
# )
#
# -
#  Sub
#  Oper
# ación
#  (
# B
# cle
# Sub
# )
#
# -
#  Tipo
#  de
#  Oper
# ación
#  (
# B
# cle
# TO
# p
# )
#
# -
#  Fecha
#  (
# B
# cl
# E
# 1
# F
# ch
# )
#
# -
#  H
# ora
#  (
# B
# cle
# 1
# H
# ra
# )
#
# -
#  Producto
#  (
# B
# cle
# 1
# Pr
# d
# )
#
# -
#  Bo
# leta
#  (
# B
# cle
# 1
# B
# ol
# )
#
# -
#  Che
# que
#  (
# B
# cle
# 1
# Ch
# q
# )
#
# -
#  Banco
#  (
# B
# cle
# 1
# B
# co
# )
#
# -
#  Suc
# ursal
#  del
#  Banco
#  (
# B
# cle
# 1
# BS
# uc
# )
#
# -
#  C
# ódigo
#  Postal
#  (
# B
# cle
# 1
# CP
# )
#
# -
#  C
# uenta
#  del
#  Lib
# rador
#  (
# B
# cle
# 1
# C
# ta
# L
# )
#
# -
#  Plaza
#  (
# B
# cle
# 1
# P
# za
# )
#
# -
#  Pl
# azo
#  (
# B
# cle
# 1
# P
# zo
# )
#
# -
#  Tipo
#  de
#  Che
# que
#  (
# B
# cle
# 1
# T
# Ch
# q
# )
#
# -
#  Import
# e
#  (
# B
# cle
# 1
# Imp
# )
#
# -
#  Estado
#  (
# B
# cle
# 1
# Est
# )
#
# -
#  Mon
# eda
#  del
#  Che
# que
#  (
# B
# cle
# 1
# M
# da
# )
#
# -
#  Mot
# ivo
#  del
#  V
# enc
# imiento
#  (
# B
# cle
# 1
# Mt
# V
# to
# )
#
# -
#  Estado
#  en
#  Pro
# ceso
#  de
#  M
# igr
# ación
#  (
# B
# cle
# 1
# ME
# st
# )
